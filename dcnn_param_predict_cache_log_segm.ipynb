# %%
from pathlib import Path
import json

DATA_ROOT = Path("synthetic_runs1T_FK_2c")  # 250-patient dataset

samples = sorted([p for p in DATA_ROOT.glob("synthetic1T_run*") if p.is_dir()])
print("DATA_ROOT exists:", DATA_ROOT.exists())
print("Num samples:", len(samples))
print("First sample:", samples[0] if samples else None)

params = json.loads((samples[0] / "parameters.json").read_text())
print("Parameter keys:", list(params.keys()))
print("Example params:", {k: params[k] for k in ("Dw", "rho")})
# Out:
# DATA_ROOT exists: True
# Num samples: 250
# First sample: synthetic_runs1T_FK_2c\synthetic1T_run100
# Parameter keys: ['th_necro_n', 'th_enhancing_p', 'th_edema_p', 'Dw', 'rho', 'lambda_np', 'sigma_np', 'D_s', 'lambda_s', 'gm_path', 'wm_path', 'NxT1_pct', 'NyT1_pct', 'NzT1_pct', 'resolution_factor', 'RatioDw_Dg', 'th_matter', 'th_necro', 'dx_mm', 'dy_mm', 'dz_mm', 'init_scale', 'time_series_solution_Nt', 'Nt_multiplier', 'output_dir']
# Example params: {'Dw': 1.459503618461283, 'rho': 0.7087988562347525}

# %%
TARGET_KEYS = ("Dw", "rho")

# %%
import random
random.seed(42)
random.shuffle(samples)

n = len(samples)
train = samples[:int(0.7*n)]
val   = samples[int(0.7*n):int(0.85*n)]
test  = samples[int(0.85*n):]

print("Split sizes:", len(train), len(val), len(test))
# Out:
# Split sizes: 175 37 38

# %%
import numpy as np
import json

def get_y(sample_dir):
    p = json.loads((sample_dir/"parameters.json").read_text())
    vals = []
    for k in TARGET_KEYS:
        v = float(p[k])
        if k == "Dw":
            v = np.log(v)   # match dataset + training
        vals.append(v)
    return np.array(vals, dtype=np.float32)

Y_train = np.stack([get_y(s) for s in train], axis=0)
Y_MEAN = Y_train.mean(axis=0)
Y_STD  = Y_train.std(axis=0) + 1e-6

print("Y_MEAN:", Y_MEAN)
print("Y_STD :", Y_STD)
# Out:
# Y_MEAN: [0.34416467 0.3797969 ]
# Y_STD : [0.9162873  0.23868617]

# %%
import numpy as np
import SimpleITK as sitk
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
import json

def read_nii(path):
    img = sitk.ReadImage(str(path))
    arr = sitk.GetArrayFromImage(img).astype(np.float32)  # (D,H,W)
    return arr

def bbox_from_mask(mask, margin=12):
    idx = np.argwhere(mask)
    if idx.size == 0:
        return None
    z0,y0,x0 = idx.min(axis=0)
    z1,y1,x1 = idx.max(axis=0) + 1
    z0 = max(z0 - margin, 0); y0 = max(y0 - margin, 0); x0 = max(x0 - margin, 0)
    z1 = min(z1 + margin, mask.shape[0]); y1 = min(y1 + margin, mask.shape[1]); x1 = min(x1 + margin, mask.shape[2])
    return (z0,z1,y0,y1,x0,x1)

def crop(arr, bb):
    z0,z1,y0,y1,x0,x1 = bb
    return arr[z0:z1, y0:y1, x0:x1]

def resize_3d(arr, out_shape=(96,96,96)):
    t = torch.from_numpy(arr)[None,None,...]
    t = F.interpolate(t, size=out_shape, mode="trilinear", align_corners=False)
    return t[0,0].numpy()

class TumorParamDatasetCached(Dataset):
    """
    Segmentation-only cached dataset:
    Input x: (1, D, H, W) from segm mask only
    Output y: normalized targets (Dw, rho, ...)
    """
    def __init__(self, sample_dirs, out_shape=(96,96,96), target_keys=("Dw","rho"), verbose=True):
        self.sample_dirs = sample_dirs
        self.out_shape = out_shape
        self.target_keys = target_keys

        self.cache = []
        if verbose:
            print(f"Caching {len(sample_dirs)} samples... (one-time cost)")

        for i, sd in enumerate(self.sample_dirs):
            x, y = self._load_one(sd)
            self.cache.append((x, y))
            if verbose and (i+1) % 10 == 0:
                print(f"  cached {i+1}/{len(sample_dirs)}")

        if verbose:
            print("Caching done.")

    def __len__(self):
        return len(self.cache)

    def __getitem__(self, idx):
        return self.cache[idx]

    def _load_one(self, sd):
        # ---- Targets (normalized using training stats) ----
        params = json.loads((sd/"parameters.json").read_text())

        vals = []
        for k in self.target_keys:
            v = float(params[k])
            if k == "Dw":
                v = np.log(v)  # keep your log(Dw) improvement
            vals.append(v)

        y_raw = np.array(vals, dtype=np.float32)
        y_norm = (y_raw - Y_MEAN) / Y_STD
        y = torch.tensor(y_norm, dtype=torch.float32)

        # ---- Input: segm only ----
        segm = read_nii(sd/"segm.nii.gz")
        mask = (segm > 0).astype(np.float32)

        bb = bbox_from_mask(mask > 0, margin=12)
        if bb is not None:
            mask = crop(mask, bb)

        mask = resize_3d(mask, self.out_shape)

        # (1, D, H, W)
        x = torch.from_numpy(mask[None, ...]).float()
        return x, y

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.cuda.amp import autocast, GradScaler


class CNN3DRegressor(nn.Module):
    def __init__(self, in_channels, out_dim):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv3d(in_channels, 32, 3, padding=1),
            nn.BatchNorm3d(32), nn.ReLU(inplace=True),
            nn.MaxPool3d(2),

            nn.Conv3d(32, 64, 3, padding=1),
            nn.BatchNorm3d(64), nn.ReLU(inplace=True),
            nn.MaxPool3d(2),

            nn.Conv3d(64, 128, 3, padding=1),
            nn.BatchNorm3d(128), nn.ReLU(inplace=True),
            nn.MaxPool3d(2),

            nn.Conv3d(128, 256, 3, padding=1),
            nn.BatchNorm3d(256), nn.ReLU(inplace=True),
        )
        self.head = nn.Sequential(
            nn.AdaptiveAvgPool3d(1),
            nn.Flatten(),
            nn.Linear(256, 128), nn.ReLU(inplace=True),
            nn.Dropout(0.2),
            nn.Linear(128, out_dim)
        )

    def forward(self, x):
        return self.head(self.features(x))

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device, torch.cuda.get_device_name(0) if device=="cuda" else "")

MODE = "segm"
OUT_SHAPE = (96,96,96)

# ---- Cache datasets (one-time preprocessing) ----
train_ds = TumorParamDatasetCached(train, out_shape=OUT_SHAPE, target_keys=TARGET_KEYS, verbose=True)
val_ds   = TumorParamDatasetCached(val,   out_shape=OUT_SHAPE, target_keys=TARGET_KEYS, verbose=True)

# ---- DataLoader settings ----
# With caching, workers aren't needed. Keep 0 for maximum stability.
NUM_WORKERS = 0

# Increase batch size now that IO/preprocessing is gone.
# Try 8 first; if you OOM, drop to 4.
BATCH_SIZE = 8

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

model = CNN3DRegressor(in_channels=1, out_dim=len(TARGET_KEYS)).to(device)
opt = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
scaler = GradScaler()
loss_fn = nn.MSELoss()
def mae(pred, y):
    return (pred - y).abs().mean()

EPOCHS = 300 

# ---- Best validation checkpoint ----
best_val_mse = float("inf")
best_state = None
best_epoch = -1

for epoch in range(1, EPOCHS+1):
    model.train()
    tr_loss = tr_mae = 0.0

    for x, y in train_loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        opt.zero_grad(set_to_none=True)
        with autocast():
            pred = model(x)
            loss = loss_fn(pred, y)

        scaler.scale(loss).backward()
        scaler.step(opt)
        scaler.update()

        tr_loss += loss.item()
        tr_mae  += mae(pred.detach(), y).item()

    model.eval()
    va_loss = va_mae = 0.0
    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)
            with autocast():
                pred = model(x)
                loss = loss_fn(pred, y)
            va_loss += loss.item()
            va_mae  += mae(pred, y).item()

    val_mse = va_loss / len(val_loader)

    # Save best model weights
    if val_mse < best_val_mse:
        best_val_mse = val_mse
        best_epoch = epoch
        best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    print(f"Epoch {epoch:03d} | train MSE {tr_loss/len(train_loader):.4f} MAE {tr_mae/len(train_loader):.4f} "
      f"| val MSE {val_mse:.4f} MAE {va_mae/len(val_loader):.4f} "
      f"| best val {best_val_mse:.4f} @ {best_epoch:03d}")

# Restore best model before testing
if best_state is not None:
    model.load_state_dict(best_state)
    print(f"\n✅ Loaded best model from epoch {best_epoch} with val MSE {best_val_mse:.6f}")
# Out:
# Device: cuda NVIDIA GeForce RTX 5080
# Caching 175 samples... (one-time cost)
#   cached 10/175
#   cached 20/175
#   cached 30/175
#   cached 40/175
#   cached 50/175
#   cached 60/175
#   cached 70/175
#   cached 80/175
#   cached 90/175
#   cached 100/175
#   cached 110/175
#   cached 120/175
#   cached 130/175
#   cached 140/175
#   cached 150/175
#   cached 160/175
#   cached 170/175
# Caching done.
# Caching 37 samples... (one-time cost)
#   cached 10/37
#   cached 20/37
#   cached 30/37
# Caching done.
# C:\Users\Grant\AppData\Local\Temp\ipykernel_7224\2683415665.py:60: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# C:\Users\Grant\AppData\Local\Temp\ipykernel_7224\2683415665.py:81: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\Grant\AppData\Local\Temp\ipykernel_7224\2683415665.py:98: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 001 | train MSE 0.7835 MAE 0.7341 | val MSE 2.2341 MAE 1.3167 | best val 2.2341 @ 001
# Epoch 002 | train MSE 0.7327 MAE 0.6877 | val MSE 0.4815 MAE 0.5303 | best val 0.4815 @ 002
# Epoch 003 | train MSE 0.7324 MAE 0.6836 | val MSE 0.5396 MAE 0.5900 | best val 0.4815 @ 002
# Epoch 004 | train MSE 0.7358 MAE 0.7065 | val MSE 0.5210 MAE 0.5643 | best val 0.4815 @ 002
# Epoch 005 | train MSE 0.6962 MAE 0.6629 | val MSE 0.7234 MAE 0.6771 | best val 0.4815 @ 002
# Epoch 006 | train MSE 0.6827 MAE 0.6656 | val MSE 0.6124 MAE 0.6250 | best val 0.4815 @ 002
# Epoch 007 | train MSE 0.6759 MAE 0.6445 | val MSE 2.5286 MAE 1.3501 | best val 0.4815 @ 002
# Epoch 008 | train MSE 0.6665 MAE 0.6672 | val MSE 0.4687 MAE 0.5104 | best val 0.4687 @ 008
# Epoch 009 | train MSE 0.6523 MAE 0.6449 | val MSE 0.8897 MAE 0.7501 | best val 0.4687 @ 008
# Epoch 010 | train MSE 0.6204 MAE 0.6393 | val MSE 0.7062 MAE 0.6695 | best val 0.4687 @ 008
# Epoch 011 | train MSE 0.6061 MAE 0.6278 | val MSE 0.5217 MAE 0.5197 | best val 0.4687 @ 008
# Epoch 012 | train MSE 0.5857 MAE 0.6135 | val MSE 1.3658 MAE 0.9555 | best val 0.4687 @ 008
# Epoch 013 | train MSE 0.5799 MAE 0.6004 | val MSE 0.6159 MAE 0.6076 | best val 0.4687 @ 008
# Epoch 014 | train MSE 0.5460 MAE 0.5815 | val MSE 1.9208 MAE 1.1034 | best val 0.4687 @ 008
# Epoch 015 | train MSE 0.5799 MAE 0.6077 | val MSE 1.5099 MAE 1.0000 | best val 0.4687 @ 008
# Epoch 016 | train MSE 0.5248 MAE 0.5760 | val MSE 0.8496 MAE 0.7427 | best val 0.4687 @ 008
# Epoch 017 | train MSE 0.5144 MAE 0.5733 | val MSE 0.4856 MAE 0.5493 | best val 0.4687 @ 008
# Epoch 018 | train MSE 0.5479 MAE 0.6079 | val MSE 4.7861 MAE 1.9392 | best val 0.4687 @ 008
# Epoch 019 | train MSE 0.5298 MAE 0.5797 | val MSE 1.2856 MAE 0.8976 | best val 0.4687 @ 008
# Epoch 020 | train MSE 0.4832 MAE 0.5601 | val MSE 0.6318 MAE 0.6214 | best val 0.4687 @ 008
# Epoch 021 | train MSE 0.4400 MAE 0.5163 | val MSE 1.7499 MAE 1.1197 | best val 0.4687 @ 008
# Epoch 022 | train MSE 0.4741 MAE 0.5411 | val MSE 1.3544 MAE 0.9902 | best val 0.4687 @ 008
# Epoch 023 | train MSE 0.4541 MAE 0.5356 | val MSE 0.4631 MAE 0.5114 | best val 0.4631 @ 023
# Epoch 024 | train MSE 0.4744 MAE 0.5483 | val MSE 3.1423 MAE 1.5810 | best val 0.4631 @ 023
# Epoch 025 | train MSE 0.4693 MAE 0.5479 | val MSE 0.9707 MAE 0.7711 | best val 0.4631 @ 023
# Epoch 026 | train MSE 0.4052 MAE 0.4988 | val MSE 0.4698 MAE 0.5544 | best val 0.4631 @ 023
# Epoch 027 | train MSE 0.4118 MAE 0.5240 | val MSE 3.7489 MAE 1.5008 | best val 0.4631 @ 023
# Epoch 028 | train MSE 0.4828 MAE 0.5499 | val MSE 0.4900 MAE 0.5605 | best val 0.4631 @ 023
# Epoch 029 | train MSE 0.4248 MAE 0.5231 | val MSE 0.8360 MAE 0.7335 | best val 0.4631 @ 023
# Epoch 030 | train MSE 0.3579 MAE 0.4700 | val MSE 1.3594 MAE 0.9765 | best val 0.4631 @ 023
# Epoch 031 | train MSE 0.3620 MAE 0.4813 | val MSE 0.7667 MAE 0.7024 | best val 0.4631 @ 023
# Epoch 032 | train MSE 0.3642 MAE 0.4704 | val MSE 1.3571 MAE 0.9617 | best val 0.4631 @ 023
# Epoch 033 | train MSE 0.3278 MAE 0.4564 | val MSE 0.3846 MAE 0.4558 | best val 0.3846 @ 033
# Epoch 034 | train MSE 0.3488 MAE 0.4638 | val MSE 0.9314 MAE 0.7845 | best val 0.3846 @ 033
# Epoch 035 | train MSE 0.3675 MAE 0.4713 | val MSE 2.0039 MAE 1.1788 | best val 0.3846 @ 033
# Epoch 036 | train MSE 0.3319 MAE 0.4509 | val MSE 0.3385 MAE 0.4472 | best val 0.3385 @ 036
# Epoch 037 | train MSE 0.3218 MAE 0.4475 | val MSE 1.1326 MAE 0.8749 | best val 0.3385 @ 036
# Epoch 038 | train MSE 0.3284 MAE 0.4585 | val MSE 0.5035 MAE 0.5258 | best val 0.3385 @ 036
# Epoch 039 | train MSE 0.2863 MAE 0.4167 | val MSE 1.7169 MAE 1.1305 | best val 0.3385 @ 036
# Epoch 040 | train MSE 0.2840 MAE 0.4144 | val MSE 0.8149 MAE 0.7140 | best val 0.3385 @ 036
# Epoch 041 | train MSE 0.2934 MAE 0.4237 | val MSE 3.9784 MAE 1.6271 | best val 0.3385 @ 036
# Epoch 042 | train MSE 0.3175 MAE 0.4438 | val MSE 34.2188 MAE 4.9779 | best val 0.3385 @ 036
# Epoch 043 | train MSE 0.3252 MAE 0.4453 | val MSE 0.3348 MAE 0.4326 | best val 0.3348 @ 043
# Epoch 044 | train MSE 0.3155 MAE 0.4385 | val MSE 1.1407 MAE 0.8599 | best val 0.3348 @ 043
# Epoch 045 | train MSE 0.3232 MAE 0.4481 | val MSE 1.7017 MAE 1.0049 | best val 0.3348 @ 043
# Epoch 046 | train MSE 0.2407 MAE 0.4008 | val MSE 0.4031 MAE 0.4815 | best val 0.3348 @ 043
# Epoch 047 | train MSE 0.2582 MAE 0.4067 | val MSE 0.8033 MAE 0.7538 | best val 0.3348 @ 043
# Epoch 048 | train MSE 0.2812 MAE 0.4262 | val MSE 1.7091 MAE 1.0669 | best val 0.3348 @ 043
# Epoch 049 | train MSE 0.2396 MAE 0.3882 | val MSE 0.5871 MAE 0.5794 | best val 0.3348 @ 043
# Epoch 050 | train MSE 0.2350 MAE 0.3864 | val MSE 1.5462 MAE 1.0119 | best val 0.3348 @ 043
# Epoch 051 | train MSE 0.2766 MAE 0.4236 | val MSE 0.7585 MAE 0.6851 | best val 0.3348 @ 043
# Epoch 052 | train MSE 0.2769 MAE 0.4148 | val MSE 0.4222 MAE 0.4813 | best val 0.3348 @ 043
# Epoch 053 | train MSE 0.2939 MAE 0.4248 | val MSE 1.3492 MAE 0.9324 | best val 0.3348 @ 043
# Epoch 054 | train MSE 0.3069 MAE 0.4365 | val MSE 0.9304 MAE 0.8083 | best val 0.3348 @ 043
# Epoch 055 | train MSE 0.2906 MAE 0.4389 | val MSE 0.4156 MAE 0.4946 | best val 0.3348 @ 043
# Epoch 056 | train MSE 0.2846 MAE 0.4154 | val MSE 4.8544 MAE 1.9453 | best val 0.3348 @ 043
# Epoch 057 | train MSE 0.2736 MAE 0.4179 | val MSE 0.3642 MAE 0.5065 | best val 0.3348 @ 043
# Epoch 058 | train MSE 0.2619 MAE 0.4075 | val MSE 0.3808 MAE 0.5169 | best val 0.3348 @ 043
# Epoch 059 | train MSE 0.2602 MAE 0.4068 | val MSE 1.3251 MAE 0.9885 | best val 0.3348 @ 043
# Epoch 060 | train MSE 0.2526 MAE 0.3957 | val MSE 1.4840 MAE 1.0195 | best val 0.3348 @ 043
# Epoch 061 | train MSE 0.2576 MAE 0.4027 | val MSE 0.3703 MAE 0.5185 | best val 0.3348 @ 043
# Epoch 062 | train MSE 0.2299 MAE 0.3774 | val MSE 0.3124 MAE 0.4189 | best val 0.3124 @ 062
# Epoch 063 | train MSE 0.2513 MAE 0.3991 | val MSE 1.1826 MAE 0.9315 | best val 0.3124 @ 062
# Epoch 064 | train MSE 0.2281 MAE 0.3755 | val MSE 0.6008 MAE 0.5864 | best val 0.3124 @ 062
# Epoch 065 | train MSE 0.2498 MAE 0.3962 | val MSE 3.5176 MAE 1.6598 | best val 0.3124 @ 062
# Epoch 066 | train MSE 0.2624 MAE 0.4047 | val MSE 0.5476 MAE 0.5852 | best val 0.3124 @ 062
# Epoch 067 | train MSE 0.2743 MAE 0.4095 | val MSE 2.2636 MAE 1.3033 | best val 0.3124 @ 062
# Epoch 068 | train MSE 0.2776 MAE 0.4161 | val MSE 0.5163 MAE 0.5964 | best val 0.3124 @ 062
# Epoch 069 | train MSE 0.2460 MAE 0.3879 | val MSE 4.1579 MAE 1.6662 | best val 0.3124 @ 062
# Epoch 070 | train MSE 0.2421 MAE 0.3849 | val MSE 0.3896 MAE 0.4791 | best val 0.3124 @ 062
# Epoch 071 | train MSE 0.2318 MAE 0.3713 | val MSE 0.5533 MAE 0.5585 | best val 0.3124 @ 062
# Epoch 072 | train MSE 0.2423 MAE 0.3997 | val MSE 1.5553 MAE 1.0332 | best val 0.3124 @ 062
# Epoch 073 | train MSE 0.2533 MAE 0.4050 | val MSE 1.8612 MAE 1.2257 | best val 0.3124 @ 062
# Epoch 074 | train MSE 0.2362 MAE 0.3873 | val MSE 0.8061 MAE 0.7821 | best val 0.3124 @ 062
# Epoch 075 | train MSE 0.2256 MAE 0.3737 | val MSE 0.5233 MAE 0.5188 | best val 0.3124 @ 062
# Epoch 076 | train MSE 0.3137 MAE 0.4311 | val MSE 0.3232 MAE 0.4295 | best val 0.3124 @ 062
# Epoch 077 | train MSE 0.2392 MAE 0.3833 | val MSE 0.5488 MAE 0.5669 | best val 0.3124 @ 062
# Epoch 078 | train MSE 0.2109 MAE 0.3679 | val MSE 1.2693 MAE 0.8974 | best val 0.3124 @ 062
# Epoch 079 | train MSE 0.2437 MAE 0.3864 | val MSE 0.3858 MAE 0.4543 | best val 0.3124 @ 062
# Epoch 080 | train MSE 0.2039 MAE 0.3518 | val MSE 0.7931 MAE 0.6881 | best val 0.3124 @ 062
# Epoch 081 | train MSE 0.2717 MAE 0.3996 | val MSE 4.9276 MAE 2.0539 | best val 0.3124 @ 062
# Epoch 082 | train MSE 0.2600 MAE 0.4067 | val MSE 1.7432 MAE 1.0371 | best val 0.3124 @ 062
# Epoch 083 | train MSE 0.1977 MAE 0.3424 | val MSE 0.7659 MAE 0.6940 | best val 0.3124 @ 062
# Epoch 084 | train MSE 0.1888 MAE 0.3395 | val MSE 0.4994 MAE 0.5025 | best val 0.3124 @ 062
# Epoch 085 | train MSE 0.2039 MAE 0.3514 | val MSE 0.3465 MAE 0.4510 | best val 0.3124 @ 062
# Epoch 086 | train MSE 0.1830 MAE 0.3291 | val MSE 1.9959 MAE 1.2574 | best val 0.3124 @ 062
# Epoch 087 | train MSE 0.2201 MAE 0.3632 | val MSE 1.0504 MAE 0.8097 | best val 0.3124 @ 062
# Epoch 088 | train MSE 0.2787 MAE 0.4095 | val MSE 2.1874 MAE 1.2732 | best val 0.3124 @ 062
# Epoch 089 | train MSE 0.2606 MAE 0.4018 | val MSE 0.4401 MAE 0.5339 | best val 0.3124 @ 062
# Epoch 090 | train MSE 0.1907 MAE 0.3433 | val MSE 0.3268 MAE 0.4006 | best val 0.3124 @ 062
# Epoch 091 | train MSE 0.2071 MAE 0.3532 | val MSE 0.3562 MAE 0.4959 | best val 0.3124 @ 062
# Epoch 092 | train MSE 0.1953 MAE 0.3475 | val MSE 1.2182 MAE 0.9426 | best val 0.3124 @ 062
# Epoch 093 | train MSE 0.2099 MAE 0.3604 | val MSE 0.3039 MAE 0.3996 | best val 0.3039 @ 093
# Epoch 094 | train MSE 0.1786 MAE 0.3332 | val MSE 0.4789 MAE 0.4925 | best val 0.3039 @ 093
# Epoch 095 | train MSE 0.2027 MAE 0.3597 | val MSE 0.4123 MAE 0.5140 | best val 0.3039 @ 093
# Epoch 096 | train MSE 0.1682 MAE 0.3282 | val MSE 1.1421 MAE 0.8688 | best val 0.3039 @ 093
# Epoch 097 | train MSE 0.1881 MAE 0.3409 | val MSE 1.7283 MAE 1.1909 | best val 0.3039 @ 093
# Epoch 098 | train MSE 0.1988 MAE 0.3543 | val MSE 1.1870 MAE 0.8558 | best val 0.3039 @ 093
# Epoch 099 | train MSE 0.2268 MAE 0.3756 | val MSE 0.6027 MAE 0.5600 | best val 0.3039 @ 093
# Epoch 100 | train MSE 0.2028 MAE 0.3640 | val MSE 0.5305 MAE 0.5455 | best val 0.3039 @ 093
# Epoch 101 | train MSE 0.2154 MAE 0.3643 | val MSE 0.4925 MAE 0.5031 | best val 0.3039 @ 093
# Epoch 102 | train MSE 0.2712 MAE 0.3982 | val MSE 2.2134 MAE 1.1762 | best val 0.3039 @ 093
# Epoch 103 | train MSE 0.2920 MAE 0.4157 | val MSE 1.5643 MAE 1.0019 | best val 0.3039 @ 093
# Epoch 104 | train MSE 0.2492 MAE 0.3833 | val MSE 0.3133 MAE 0.4356 | best val 0.3039 @ 093
# Epoch 105 | train MSE 0.1805 MAE 0.3371 | val MSE 0.3342 MAE 0.4142 | best val 0.3039 @ 093
# Epoch 106 | train MSE 0.1683 MAE 0.3247 | val MSE 0.3195 MAE 0.4500 | best val 0.3039 @ 093
# Epoch 107 | train MSE 0.2100 MAE 0.3482 | val MSE 0.3800 MAE 0.4397 | best val 0.3039 @ 093
# Epoch 108 | train MSE 0.1813 MAE 0.3375 | val MSE 3.3959 MAE 1.5902 | best val 0.3039 @ 093
# Epoch 109 | train MSE 0.1893 MAE 0.3429 | val MSE 0.5682 MAE 0.5287 | best val 0.3039 @ 093
# Epoch 110 | train MSE 0.2439 MAE 0.3969 | val MSE 0.5386 MAE 0.5762 | best val 0.3039 @ 093
# Epoch 111 | train MSE 0.1942 MAE 0.3479 | val MSE 1.4720 MAE 1.0260 | best val 0.3039 @ 093
# Epoch 112 | train MSE 0.2027 MAE 0.3546 | val MSE 1.5441 MAE 1.0153 | best val 0.3039 @ 093
# Epoch 113 | train MSE 0.1596 MAE 0.3063 | val MSE 0.3442 MAE 0.4437 | best val 0.3039 @ 093
# Epoch 114 | train MSE 0.1944 MAE 0.3481 | val MSE 0.6027 MAE 0.6511 | best val 0.3039 @ 093
# Epoch 115 | train MSE 0.1614 MAE 0.3068 | val MSE 1.5732 MAE 1.0653 | best val 0.3039 @ 093
# Epoch 116 | train MSE 0.1936 MAE 0.3432 | val MSE 1.1711 MAE 0.9094 | best val 0.3039 @ 093
# Epoch 117 | train MSE 0.1377 MAE 0.3002 | val MSE 0.4252 MAE 0.4574 | best val 0.3039 @ 093
# Epoch 118 | train MSE 0.1632 MAE 0.3163 | val MSE 1.7314 MAE 1.1012 | best val 0.3039 @ 093
# Epoch 119 | train MSE 0.1979 MAE 0.3485 | val MSE 1.1445 MAE 0.9497 | best val 0.3039 @ 093
# Epoch 120 | train MSE 0.2282 MAE 0.3748 | val MSE 3.3383 MAE 1.5671 | best val 0.3039 @ 093
# Epoch 121 | train MSE 0.2226 MAE 0.3691 | val MSE 0.9252 MAE 0.7532 | best val 0.3039 @ 093
# Epoch 122 | train MSE 0.2164 MAE 0.3640 | val MSE 0.6649 MAE 0.6838 | best val 0.3039 @ 093
# Epoch 123 | train MSE 0.2072 MAE 0.3522 | val MSE 0.4766 MAE 0.4893 | best val 0.3039 @ 093
# Epoch 124 | train MSE 0.1784 MAE 0.3307 | val MSE 1.9842 MAE 1.2033 | best val 0.3039 @ 093
# Epoch 125 | train MSE 0.1937 MAE 0.3460 | val MSE 0.8002 MAE 0.7146 | best val 0.3039 @ 093
# Epoch 126 | train MSE 0.1678 MAE 0.3251 | val MSE 0.7391 MAE 0.7292 | best val 0.3039 @ 093
# Epoch 127 | train MSE 0.1634 MAE 0.3199 | val MSE 0.2941 MAE 0.3815 | best val 0.2941 @ 127
# Epoch 128 | train MSE 0.1925 MAE 0.3427 | val MSE 2.1550 MAE 1.2914 | best val 0.2941 @ 127
# Epoch 129 | train MSE 0.2179 MAE 0.3700 | val MSE 0.4229 MAE 0.4413 | best val 0.2941 @ 127
# Epoch 130 | train MSE 0.1683 MAE 0.3256 | val MSE 0.4961 MAE 0.5583 | best val 0.2941 @ 127
# Epoch 131 | train MSE 0.1491 MAE 0.3003 | val MSE 0.3645 MAE 0.4539 | best val 0.2941 @ 127
# Epoch 132 | train MSE 0.1679 MAE 0.3262 | val MSE 2.3008 MAE 1.2535 | best val 0.2941 @ 127
# Epoch 133 | train MSE 0.1442 MAE 0.3019 | val MSE 0.3364 MAE 0.3896 | best val 0.2941 @ 127
# Epoch 134 | train MSE 0.1734 MAE 0.3154 | val MSE 0.5386 MAE 0.5125 | best val 0.2941 @ 127
# Epoch 135 | train MSE 0.1541 MAE 0.3085 | val MSE 0.7104 MAE 0.6441 | best val 0.2941 @ 127
# Epoch 136 | train MSE 0.1600 MAE 0.3167 | val MSE 1.2143 MAE 0.8837 | best val 0.2941 @ 127
# Epoch 137 | train MSE 0.1439 MAE 0.2978 | val MSE 0.3497 MAE 0.4086 | best val 0.2941 @ 127
# Epoch 138 | train MSE 0.1620 MAE 0.3079 | val MSE 0.3885 MAE 0.4988 | best val 0.2941 @ 127
# Epoch 139 | train MSE 0.1622 MAE 0.3151 | val MSE 0.4593 MAE 0.4742 | best val 0.2941 @ 127
# Epoch 140 | train MSE 0.1752 MAE 0.3211 | val MSE 0.6105 MAE 0.6122 | best val 0.2941 @ 127
# Epoch 141 | train MSE 0.1967 MAE 0.3431 | val MSE 0.9667 MAE 0.7644 | best val 0.2941 @ 127
# Epoch 142 | train MSE 0.1943 MAE 0.3463 | val MSE 0.4196 MAE 0.4553 | best val 0.2941 @ 127
# Epoch 143 | train MSE 0.1588 MAE 0.3137 | val MSE 0.3549 MAE 0.4596 | best val 0.2941 @ 127
# Epoch 144 | train MSE 0.1700 MAE 0.3261 | val MSE 1.0456 MAE 0.8561 | best val 0.2941 @ 127
# Epoch 145 | train MSE 0.1718 MAE 0.3302 | val MSE 1.7555 MAE 1.1789 | best val 0.2941 @ 127
# Epoch 146 | train MSE 0.1867 MAE 0.3415 | val MSE 0.6236 MAE 0.5802 | best val 0.2941 @ 127
# Epoch 147 | train MSE 0.1754 MAE 0.3299 | val MSE 10.2376 MAE 2.8273 | best val 0.2941 @ 127
# Epoch 148 | train MSE 0.2066 MAE 0.3532 | val MSE 0.5367 MAE 0.5808 | best val 0.2941 @ 127
# Epoch 149 | train MSE 0.2042 MAE 0.3569 | val MSE 1.1908 MAE 0.9506 | best val 0.2941 @ 127
# Epoch 150 | train MSE 0.1766 MAE 0.3292 | val MSE 0.4308 MAE 0.4531 | best val 0.2941 @ 127
# Epoch 151 | train MSE 0.1467 MAE 0.2933 | val MSE 3.3009 MAE 1.6496 | best val 0.2941 @ 127
# Epoch 152 | train MSE 0.1628 MAE 0.3118 | val MSE 0.4808 MAE 0.5265 | best val 0.2941 @ 127
# Epoch 153 | train MSE 0.1631 MAE 0.3177 | val MSE 0.6555 MAE 0.6377 | best val 0.2941 @ 127
# Epoch 154 | train MSE 0.1643 MAE 0.3142 | val MSE 0.3712 MAE 0.4908 | best val 0.2941 @ 127
# Epoch 155 | train MSE 0.1642 MAE 0.3150 | val MSE 1.3763 MAE 0.9433 | best val 0.2941 @ 127
# Epoch 156 | train MSE 0.1672 MAE 0.3209 | val MSE 0.5144 MAE 0.5058 | best val 0.2941 @ 127
# Epoch 157 | train MSE 0.1684 MAE 0.3260 | val MSE 0.7814 MAE 0.7355 | best val 0.2941 @ 127
# Epoch 158 | train MSE 0.1531 MAE 0.3014 | val MSE 0.5213 MAE 0.4986 | best val 0.2941 @ 127
# Epoch 159 | train MSE 0.1768 MAE 0.3338 | val MSE 0.9080 MAE 0.7072 | best val 0.2941 @ 127
# Epoch 160 | train MSE 0.1502 MAE 0.3029 | val MSE 0.8674 MAE 0.7216 | best val 0.2941 @ 127
# Epoch 161 | train MSE 0.1526 MAE 0.2994 | val MSE 1.5275 MAE 1.0381 | best val 0.2941 @ 127
# Epoch 162 | train MSE 0.1852 MAE 0.3423 | val MSE 1.9505 MAE 1.2569 | best val 0.2941 @ 127
# Epoch 163 | train MSE 0.1619 MAE 0.3144 | val MSE 3.4066 MAE 1.6963 | best val 0.2941 @ 127
# Epoch 164 | train MSE 0.1982 MAE 0.3558 | val MSE 0.4336 MAE 0.4816 | best val 0.2941 @ 127
# Epoch 165 | train MSE 0.1758 MAE 0.3258 | val MSE 0.3467 MAE 0.3827 | best val 0.2941 @ 127
# Epoch 166 | train MSE 0.1578 MAE 0.3071 | val MSE 0.6695 MAE 0.6136 | best val 0.2941 @ 127
# Epoch 167 | train MSE 0.2083 MAE 0.3491 | val MSE 0.6854 MAE 0.6954 | best val 0.2941 @ 127
# Epoch 168 | train MSE 0.1793 MAE 0.3273 | val MSE 0.4485 MAE 0.4810 | best val 0.2941 @ 127
# Epoch 169 | train MSE 0.1560 MAE 0.3012 | val MSE 2.7466 MAE 1.5161 | best val 0.2941 @ 127
# Epoch 170 | train MSE 0.1658 MAE 0.3187 | val MSE 0.4096 MAE 0.4668 | best val 0.2941 @ 127
# Epoch 171 | train MSE 0.1454 MAE 0.3035 | val MSE 0.3425 MAE 0.4286 | best val 0.2941 @ 127
# Epoch 172 | train MSE 0.1573 MAE 0.3059 | val MSE 1.6772 MAE 1.1077 | best val 0.2941 @ 127
# Epoch 173 | train MSE 0.1563 MAE 0.3078 | val MSE 0.3586 MAE 0.4182 | best val 0.2941 @ 127
# Epoch 174 | train MSE 0.1646 MAE 0.3137 | val MSE 0.4965 MAE 0.5066 | best val 0.2941 @ 127
# Epoch 175 | train MSE 0.1869 MAE 0.3344 | val MSE 1.5694 MAE 1.0803 | best val 0.2941 @ 127
# Epoch 176 | train MSE 0.1655 MAE 0.3228 | val MSE 0.8591 MAE 0.7001 | best val 0.2941 @ 127
# Epoch 177 | train MSE 0.1499 MAE 0.3025 | val MSE 0.7372 MAE 0.6268 | best val 0.2941 @ 127
# Epoch 178 | train MSE 0.1454 MAE 0.3004 | val MSE 2.4175 MAE 1.3890 | best val 0.2941 @ 127
# Epoch 179 | train MSE 0.1916 MAE 0.3370 | val MSE 0.8357 MAE 0.6849 | best val 0.2941 @ 127
# Epoch 180 | train MSE 0.1343 MAE 0.2856 | val MSE 0.4185 MAE 0.5289 | best val 0.2941 @ 127
# Epoch 181 | train MSE 0.1473 MAE 0.2981 | val MSE 0.5035 MAE 0.5355 | best val 0.2941 @ 127
# Epoch 182 | train MSE 0.1518 MAE 0.3085 | val MSE 0.3669 MAE 0.4033 | best val 0.2941 @ 127
# Epoch 183 | train MSE 0.1344 MAE 0.2918 | val MSE 1.6296 MAE 1.0105 | best val 0.2941 @ 127
# Epoch 184 | train MSE 0.1581 MAE 0.3088 | val MSE 4.2937 MAE 1.8367 | best val 0.2941 @ 127
# Epoch 185 | train MSE 0.1491 MAE 0.3094 | val MSE 0.3422 MAE 0.3821 | best val 0.2941 @ 127
# Epoch 186 | train MSE 0.1329 MAE 0.2863 | val MSE 0.7016 MAE 0.6243 | best val 0.2941 @ 127
# Epoch 187 | train MSE 0.1326 MAE 0.2857 | val MSE 0.4691 MAE 0.5298 | best val 0.2941 @ 127
# Epoch 188 | train MSE 0.1550 MAE 0.3038 | val MSE 0.6468 MAE 0.6093 | best val 0.2941 @ 127
# Epoch 189 | train MSE 0.1619 MAE 0.3126 | val MSE 3.3054 MAE 1.5346 | best val 0.2941 @ 127
# Epoch 190 | train MSE 0.1498 MAE 0.3011 | val MSE 0.6168 MAE 0.5595 | best val 0.2941 @ 127
# Epoch 191 | train MSE 0.1324 MAE 0.2813 | val MSE 1.0422 MAE 0.8271 | best val 0.2941 @ 127
# Epoch 192 | train MSE 0.1251 MAE 0.2712 | val MSE 0.3501 MAE 0.4050 | best val 0.2941 @ 127
# Epoch 193 | train MSE 0.1221 MAE 0.2667 | val MSE 0.4659 MAE 0.4868 | best val 0.2941 @ 127
# Epoch 194 | train MSE 0.1955 MAE 0.3548 | val MSE 0.9028 MAE 0.7503 | best val 0.2941 @ 127
# Epoch 195 | train MSE 0.1523 MAE 0.3049 | val MSE 2.3060 MAE 1.2096 | best val 0.2941 @ 127
# Epoch 196 | train MSE 0.1365 MAE 0.2888 | val MSE 2.0339 MAE 1.2936 | best val 0.2941 @ 127
# Epoch 197 | train MSE 0.1556 MAE 0.3076 | val MSE 0.4767 MAE 0.5331 | best val 0.2941 @ 127
# Epoch 198 | train MSE 0.1459 MAE 0.2926 | val MSE 10.0266 MAE 2.8298 | best val 0.2941 @ 127
# Epoch 199 | train MSE 0.1486 MAE 0.3017 | val MSE 0.3602 MAE 0.4112 | best val 0.2941 @ 127
# Epoch 200 | train MSE 0.1753 MAE 0.3350 | val MSE 0.6020 MAE 0.5800 | best val 0.2941 @ 127
# Epoch 201 | train MSE 0.2080 MAE 0.3656 | val MSE 1.6535 MAE 1.0651 | best val 0.2941 @ 127
# Epoch 202 | train MSE 0.2214 MAE 0.3652 | val MSE 0.5238 MAE 0.5733 | best val 0.2941 @ 127
# Epoch 203 | train MSE 0.1356 MAE 0.2878 | val MSE 0.5561 MAE 0.5245 | best val 0.2941 @ 127
# Epoch 204 | train MSE 0.1517 MAE 0.3042 | val MSE 0.5633 MAE 0.5291 | best val 0.2941 @ 127
# Epoch 205 | train MSE 0.1682 MAE 0.3145 | val MSE 0.5075 MAE 0.5720 | best val 0.2941 @ 127
# Epoch 206 | train MSE 0.1392 MAE 0.2922 | val MSE 0.4381 MAE 0.4574 | best val 0.2941 @ 127
# Epoch 207 | train MSE 0.1563 MAE 0.3158 | val MSE 0.9088 MAE 0.7691 | best val 0.2941 @ 127
# Epoch 208 | train MSE 0.1474 MAE 0.3042 | val MSE 0.4166 MAE 0.5408 | best val 0.2941 @ 127
# Epoch 209 | train MSE 0.1616 MAE 0.3191 | val MSE 1.1172 MAE 0.8631 | best val 0.2941 @ 127
# Epoch 210 | train MSE 0.1735 MAE 0.3281 | val MSE 0.2773 MAE 0.3866 | best val 0.2773 @ 210
# Epoch 211 | train MSE 0.1564 MAE 0.2982 | val MSE 0.7491 MAE 0.6679 | best val 0.2773 @ 210
# Epoch 212 | train MSE 0.1491 MAE 0.3136 | val MSE 1.2248 MAE 0.9186 | best val 0.2773 @ 210
# Epoch 213 | train MSE 0.1410 MAE 0.2902 | val MSE 0.3440 MAE 0.3930 | best val 0.2773 @ 210
# Epoch 214 | train MSE 0.1501 MAE 0.3030 | val MSE 1.9245 MAE 1.2130 | best val 0.2773 @ 210
# Epoch 215 | train MSE 0.1704 MAE 0.3243 | val MSE 0.4196 MAE 0.4687 | best val 0.2773 @ 210
# Epoch 216 | train MSE 0.1350 MAE 0.2883 | val MSE 0.9712 MAE 0.8391 | best val 0.2773 @ 210
# Epoch 217 | train MSE 0.1519 MAE 0.3094 | val MSE 0.8286 MAE 0.7395 | best val 0.2773 @ 210
# Epoch 218 | train MSE 0.1594 MAE 0.3064 | val MSE 0.7489 MAE 0.6700 | best val 0.2773 @ 210
# Epoch 219 | train MSE 0.1217 MAE 0.2678 | val MSE 0.2954 MAE 0.3693 | best val 0.2773 @ 210
# Epoch 220 | train MSE 0.1753 MAE 0.3319 | val MSE 0.4319 MAE 0.5016 | best val 0.2773 @ 210
# Epoch 221 | train MSE 0.1381 MAE 0.2883 | val MSE 0.6628 MAE 0.6692 | best val 0.2773 @ 210
# Epoch 222 | train MSE 0.1682 MAE 0.3145 | val MSE 2.3899 MAE 1.3696 | best val 0.2773 @ 210
# Epoch 223 | train MSE 0.1539 MAE 0.3106 | val MSE 0.4878 MAE 0.4912 | best val 0.2773 @ 210
# Epoch 224 | train MSE 0.1268 MAE 0.2832 | val MSE 0.3707 MAE 0.4204 | best val 0.2773 @ 210
# Epoch 225 | train MSE 0.1372 MAE 0.2837 | val MSE 0.6387 MAE 0.6279 | best val 0.2773 @ 210
# Epoch 226 | train MSE 0.1541 MAE 0.3021 | val MSE 0.4104 MAE 0.4903 | best val 0.2773 @ 210
# Epoch 227 | train MSE 0.1385 MAE 0.2959 | val MSE 0.4933 MAE 0.5077 | best val 0.2773 @ 210
# Epoch 228 | train MSE 0.1408 MAE 0.2951 | val MSE 0.6920 MAE 0.6246 | best val 0.2773 @ 210
# Epoch 229 | train MSE 0.1542 MAE 0.3076 | val MSE 0.6467 MAE 0.6220 | best val 0.2773 @ 210
# Epoch 230 | train MSE 0.1173 MAE 0.2618 | val MSE 0.9357 MAE 0.7332 | best val 0.2773 @ 210
# Epoch 231 | train MSE 0.1430 MAE 0.3006 | val MSE 2.5649 MAE 1.4617 | best val 0.2773 @ 210
# Epoch 232 | train MSE 0.1239 MAE 0.2750 | val MSE 0.3910 MAE 0.4877 | best val 0.2773 @ 210
# Epoch 233 | train MSE 0.1357 MAE 0.2831 | val MSE 2.3454 MAE 1.1934 | best val 0.2773 @ 210
# Epoch 234 | train MSE 0.1659 MAE 0.3144 | val MSE 0.8238 MAE 0.7517 | best val 0.2773 @ 210
# Epoch 235 | train MSE 0.1411 MAE 0.2981 | val MSE 0.6603 MAE 0.5895 | best val 0.2773 @ 210
# Epoch 236 | train MSE 0.1329 MAE 0.2836 | val MSE 1.4097 MAE 0.8822 | best val 0.2773 @ 210
# Epoch 237 | train MSE 0.1267 MAE 0.2878 | val MSE 0.8221 MAE 0.6803 | best val 0.2773 @ 210
# Epoch 238 | train MSE 0.1476 MAE 0.3105 | val MSE 0.4232 MAE 0.5103 | best val 0.2773 @ 210
# Epoch 239 | train MSE 0.1541 MAE 0.3128 | val MSE 2.0199 MAE 1.2059 | best val 0.2773 @ 210
# Epoch 240 | train MSE 0.1442 MAE 0.3028 | val MSE 0.7452 MAE 0.6250 | best val 0.2773 @ 210
# Epoch 241 | train MSE 0.1334 MAE 0.2849 | val MSE 1.5355 MAE 1.0334 | best val 0.2773 @ 210
# Epoch 242 | train MSE 0.1336 MAE 0.2907 | val MSE 0.8689 MAE 0.7276 | best val 0.2773 @ 210
# Epoch 243 | train MSE 0.1268 MAE 0.2810 | val MSE 0.6286 MAE 0.5995 | best val 0.2773 @ 210
# Epoch 244 | train MSE 0.1300 MAE 0.2836 | val MSE 2.7871 MAE 1.4606 | best val 0.2773 @ 210
# Epoch 245 | train MSE 0.1189 MAE 0.2733 | val MSE 0.4989 MAE 0.5123 | best val 0.2773 @ 210
# Epoch 246 | train MSE 0.1322 MAE 0.2891 | val MSE 1.3596 MAE 0.9729 | best val 0.2773 @ 210
# Epoch 247 | train MSE 0.1106 MAE 0.2628 | val MSE 0.5715 MAE 0.5257 | best val 0.2773 @ 210
# Epoch 248 | train MSE 0.1438 MAE 0.3038 | val MSE 0.3804 MAE 0.4340 | best val 0.2773 @ 210
# Epoch 249 | train MSE 0.1504 MAE 0.3110 | val MSE 0.3828 MAE 0.4423 | best val 0.2773 @ 210
# Epoch 250 | train MSE 0.1394 MAE 0.2979 | val MSE 4.2393 MAE 1.9021 | best val 0.2773 @ 210
# Epoch 251 | train MSE 0.1589 MAE 0.3106 | val MSE 0.5768 MAE 0.5483 | best val 0.2773 @ 210
# Epoch 252 | train MSE 0.1024 MAE 0.2508 | val MSE 1.1943 MAE 0.8771 | best val 0.2773 @ 210
# Epoch 253 | train MSE 0.1367 MAE 0.2909 | val MSE 0.8546 MAE 0.7785 | best val 0.2773 @ 210
# Epoch 254 | train MSE 0.1729 MAE 0.3227 | val MSE 1.2830 MAE 0.9027 | best val 0.2773 @ 210
# Epoch 255 | train MSE 0.1372 MAE 0.2876 | val MSE 0.4185 MAE 0.4908 | best val 0.2773 @ 210
# Epoch 256 | train MSE 0.1631 MAE 0.3127 | val MSE 1.9399 MAE 1.1162 | best val 0.2773 @ 210
# Epoch 257 | train MSE 0.1177 MAE 0.2729 | val MSE 3.4808 MAE 1.6429 | best val 0.2773 @ 210
# Epoch 258 | train MSE 0.1425 MAE 0.3018 | val MSE 1.1773 MAE 0.8900 | best val 0.2773 @ 210
# Epoch 259 | train MSE 0.1403 MAE 0.2879 | val MSE 0.8118 MAE 0.6723 | best val 0.2773 @ 210
# Epoch 260 | train MSE 0.1601 MAE 0.3109 | val MSE 0.5351 MAE 0.5244 | best val 0.2773 @ 210
# Epoch 261 | train MSE 0.1198 MAE 0.2710 | val MSE 0.6509 MAE 0.6649 | best val 0.2773 @ 210
# Epoch 262 | train MSE 0.1342 MAE 0.2824 | val MSE 0.8137 MAE 0.6748 | best val 0.2773 @ 210
# Epoch 263 | train MSE 0.1327 MAE 0.2893 | val MSE 0.9961 MAE 0.7998 | best val 0.2773 @ 210
# Epoch 264 | train MSE 0.1420 MAE 0.2905 | val MSE 0.6688 MAE 0.6315 | best val 0.2773 @ 210
# Epoch 265 | train MSE 0.1211 MAE 0.2676 | val MSE 0.9577 MAE 0.8185 | best val 0.2773 @ 210
# Epoch 266 | train MSE 0.1420 MAE 0.2916 | val MSE 1.1124 MAE 0.8509 | best val 0.2773 @ 210
# Epoch 267 | train MSE 0.1142 MAE 0.2603 | val MSE 0.4595 MAE 0.5206 | best val 0.2773 @ 210
# Epoch 268 | train MSE 0.1295 MAE 0.2862 | val MSE 1.9105 MAE 1.1547 | best val 0.2773 @ 210
# Epoch 269 | train MSE 0.1078 MAE 0.2592 | val MSE 1.1604 MAE 0.8622 | best val 0.2773 @ 210
# Epoch 270 | train MSE 0.1195 MAE 0.2687 | val MSE 0.7172 MAE 0.6049 | best val 0.2773 @ 210
# Epoch 271 | train MSE 0.1018 MAE 0.2469 | val MSE 1.3161 MAE 0.9554 | best val 0.2773 @ 210
# Epoch 272 | train MSE 0.1342 MAE 0.2886 | val MSE 0.6942 MAE 0.5895 | best val 0.2773 @ 210
# Epoch 273 | train MSE 0.1190 MAE 0.2684 | val MSE 0.4639 MAE 0.5433 | best val 0.2773 @ 210
# Epoch 274 | train MSE 0.1296 MAE 0.2834 | val MSE 0.4510 MAE 0.4832 | best val 0.2773 @ 210
# Epoch 275 | train MSE 0.1357 MAE 0.2869 | val MSE 2.5002 MAE 1.3800 | best val 0.2773 @ 210
# Epoch 276 | train MSE 0.1464 MAE 0.3022 | val MSE 0.9859 MAE 0.8097 | best val 0.2773 @ 210
# Epoch 277 | train MSE 0.1576 MAE 0.3148 | val MSE 0.7077 MAE 0.6688 | best val 0.2773 @ 210
# Epoch 278 | train MSE 0.1465 MAE 0.2944 | val MSE 1.1217 MAE 0.9099 | best val 0.2773 @ 210
# Epoch 279 | train MSE 0.1239 MAE 0.2716 | val MSE 0.3439 MAE 0.4353 | best val 0.2773 @ 210
# Epoch 280 | train MSE 0.1151 MAE 0.2665 | val MSE 0.2952 MAE 0.3675 | best val 0.2773 @ 210
# Epoch 281 | train MSE 0.0944 MAE 0.2440 | val MSE 0.5943 MAE 0.6347 | best val 0.2773 @ 210
# Epoch 282 | train MSE 0.1131 MAE 0.2581 | val MSE 0.3953 MAE 0.4287 | best val 0.2773 @ 210
# Epoch 283 | train MSE 0.1253 MAE 0.2726 | val MSE 0.3789 MAE 0.4189 | best val 0.2773 @ 210
# Epoch 284 | train MSE 0.1412 MAE 0.2924 | val MSE 1.4325 MAE 0.9545 | best val 0.2773 @ 210
# Epoch 285 | train MSE 0.1154 MAE 0.2702 | val MSE 0.3195 MAE 0.4027 | best val 0.2773 @ 210
# Epoch 286 | train MSE 0.1572 MAE 0.3101 | val MSE 1.3121 MAE 0.9893 | best val 0.2773 @ 210
# Epoch 287 | train MSE 0.1327 MAE 0.2913 | val MSE 0.3003 MAE 0.4120 | best val 0.2773 @ 210
# Epoch 288 | train MSE 0.1249 MAE 0.2753 | val MSE 0.4378 MAE 0.5140 | best val 0.2773 @ 210
# Epoch 289 | train MSE 0.1115 MAE 0.2570 | val MSE 0.7584 MAE 0.6797 | best val 0.2773 @ 210
# Epoch 290 | train MSE 0.1266 MAE 0.2844 | val MSE 0.3376 MAE 0.3821 | best val 0.2773 @ 210
# Epoch 291 | train MSE 0.1470 MAE 0.3004 | val MSE 0.6002 MAE 0.5749 | best val 0.2773 @ 210
# Epoch 292 | train MSE 0.1374 MAE 0.2911 | val MSE 0.3620 MAE 0.4818 | best val 0.2773 @ 210
# Epoch 293 | train MSE 0.1171 MAE 0.2739 | val MSE 0.5590 MAE 0.5563 | best val 0.2773 @ 210
# Epoch 294 | train MSE 0.1552 MAE 0.3188 | val MSE 1.3230 MAE 0.9795 | best val 0.2773 @ 210
# Epoch 295 | train MSE 0.1422 MAE 0.2964 | val MSE 0.6028 MAE 0.5875 | best val 0.2773 @ 210
# Epoch 296 | train MSE 0.1267 MAE 0.2813 | val MSE 0.5421 MAE 0.5971 | best val 0.2773 @ 210
# Epoch 297 | train MSE 0.1364 MAE 0.2857 | val MSE 0.7088 MAE 0.6307 | best val 0.2773 @ 210
# Epoch 298 | train MSE 0.1367 MAE 0.2941 | val MSE 3.3834 MAE 1.5973 | best val 0.2773 @ 210
# Epoch 299 | train MSE 0.1325 MAE 0.2826 | val MSE 2.0038 MAE 1.2955 | best val 0.2773 @ 210
# Epoch 300 | train MSE 0.1633 MAE 0.3259 | val MSE 0.4653 MAE 0.4962 | best val 0.2773 @ 210
#
# ✅ Loaded best model from epoch 210 with val MSE 0.277310

# %%
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torch

test_ds = TumorParamDatasetCached(test, out_shape=OUT_SHAPE, target_keys=TARGET_KEYS, verbose=True)
test_loader = DataLoader(test_ds, batch_size=1, shuffle=False, num_workers=0, pin_memory=True)

model.eval()
preds_norm, trues_norm = [], []
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device, non_blocking=True)
        pred = model(x).cpu().numpy()[0]
        preds_norm.append(pred)
        trues_norm.append(y.numpy()[0])

preds_norm = np.array(preds_norm)
trues_norm = np.array(trues_norm)

# Denormalize back to original parameter scale
preds = preds_norm * Y_STD + Y_MEAN
trues = trues_norm * Y_STD + Y_MEAN

# If Dw was trained in log-space, convert it back
for i, k in enumerate(TARGET_KEYS):
    if k == "Dw":
        preds[:, i] = np.exp(preds[:, i])
        trues[:, i] = np.exp(trues[:, i])

for i,k in enumerate(TARGET_KEYS):
    mae_i = np.abs(preds[:,i] - trues[:,i]).mean()
    rmse_i = np.sqrt(((preds[:,i] - trues[:,i])**2).mean())
    print(f"{k}: MAE={mae_i:.6f} RMSE={rmse_i:.6f}")

for i,k in enumerate(TARGET_KEYS):
    plt.figure()
    plt.scatter(trues[:,i], preds[:,i])
    mn = min(trues[:,i].min(), preds[:,i].min())
    mx = max(trues[:,i].max(), preds[:,i].max())
    plt.plot([mn,mx],[mn,mx])
    plt.xlabel("True")
    plt.ylabel("Predicted")
    plt.title(f"{k}: Predicted vs True")
    plt.show()
# Out:
# Caching 38 samples... (one-time cost)
#   cached 10/38
#   cached 20/38
#   cached 30/38
# Caching done.
# Dw: MAE=0.690880 RMSE=0.852790
# rho: MAE=0.078835 RMSE=0.099134

# %%
import torch

torch.save({
    "model_state": model.state_dict(),
    "target_keys": TARGET_KEYS,
    "mode": MODE,
    "out_shape": OUT_SHAPE,
    "y_mean": Y_MEAN,
    "y_std": Y_STD,
}, "dcnn_param_model.pt")

print("Saved -> dcnn_param_model.pt")
# Out:
# Saved -> dcnn_param_model.pt
