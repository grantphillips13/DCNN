# %%
from pathlib import Path
import json

DATA_ROOT = Path("batch_50_random")  # <-- CHANGE THIS

samples = sorted([p for p in DATA_ROOT.glob("sample_*") if p.is_dir()])
print("DATA_ROOT exists:", DATA_ROOT.exists())
print("Num samples:", len(samples))
print("First sample:", samples[0] if samples else None)

params = json.loads((samples[0] / "parameters.json").read_text())
print("Parameter keys:", list(params.keys()))
print("Example params:", params)
# Out:
# DATA_ROOT exists: True
# Num samples: 50
# First sample: batch_50_random\sample_0000
# Parameter keys: ['th_necro_n', 'th_enhancing_p', 'th_edema_p', 'Dw', 'rho', 'lambda_np', 'sigma_np', 'D_s', 'lambda_s', 'gm_path', 'wm_path', 'NxT1_pct', 'NyT1_pct', 'NzT1_pct', 'resolution_factor', 'RatioDw_Dg', 'th_matter', 'th_necro', 'dx_mm', 'dy_mm', 'dz_mm', 'init_scale', 'time_series_solution_Nt', 'Nt_multiplier', 'output_dir']
# Example params: {'th_necro_n': 0.15621088666940686, 'th_enhancing_p': 0.25720457300353083, 'th_edema_p': 0.24548647782429914, 'Dw': 1.4363502971184063, 'rho': 0.4778214378844623, 'lambda_np': 0.4659969709057026, 'sigma_np': 0.3993292420985183, 'D_s': 0.8900466011060912, 'lambda_s': 0.055238410897498764, 'gm_path': './dataset/GM.nii.gz', 'wm_path': './dataset/WM.nii.gz', 'NxT1_pct': 0.36742508365045984, 'NyT1_pct': 0.6098528437324806, 'NzT1_pct': 0.5303345035229626, 'resolution_factor': 0.65, 'RatioDw_Dg': 17.48663961200633, 'th_matter': 0.1, 'th_necro': 0.9, 'dx_mm': 1.0, 'dy_mm': 1.0, 'dz_mm': 1.0, 'init_scale': 0.9486373774747934, 'time_series_solution_Nt': 8, 'Nt_multiplier': 10, 'output_dir': 'synthetic_gens\\batch_50_random\\sample_0000'}

# %%
TARGET_KEYS = ("Dw", "rho")

# %%
import random
random.seed(42)
random.shuffle(samples)

n = len(samples)
train = samples[:int(0.7*n)]
val   = samples[int(0.7*n):int(0.85*n)]
test  = samples[int(0.85*n):]

print("Split sizes:", len(train), len(val), len(test))
# Out:
# Split sizes: 35 7 8

# %%
import numpy as np
import json

def get_y(sample_dir):
    p = json.loads((sample_dir/"parameters.json").read_text())
    vals = []
    for k in TARGET_KEYS:
        v = float(p[k])
        if k == "Dw":
            v = np.log(v)   # match dataset + training
        vals.append(v)
    return np.array(vals, dtype=np.float32)

Y_train = np.stack([get_y(s) for s in train], axis=0)
Y_MEAN = Y_train.mean(axis=0)
Y_STD  = Y_train.std(axis=0) + 1e-6

print("Y_MEAN:", Y_MEAN)
print("Y_STD :", Y_STD)
# Out:
# Y_MEAN: [0.4376044 0.2844008]
# Y_STD : [0.561492   0.13039392]

# %%
import numpy as np
import SimpleITK as sitk
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
import json

def read_nii(path):
    img = sitk.ReadImage(str(path))
    arr = sitk.GetArrayFromImage(img).astype(np.float32)  # (D,H,W)
    return arr

def bbox_from_mask(mask, margin=12):
    idx = np.argwhere(mask)
    if idx.size == 0:
        return None
    z0,y0,x0 = idx.min(axis=0)
    z1,y1,x1 = idx.max(axis=0) + 1
    z0 = max(z0 - margin, 0); y0 = max(y0 - margin, 0); x0 = max(x0 - margin, 0)
    z1 = min(z1 + margin, mask.shape[0]); y1 = min(y1 + margin, mask.shape[1]); x1 = min(x1 + margin, mask.shape[2])
    return (z0,z1,y0,y1,x0,x1)

def crop(arr, bb):
    z0,z1,y0,y1,x0,x1 = bb
    return arr[z0:z1, y0:y1, x0:x1]

def resize_3d(arr, out_shape=(96,96,96)):
    t = torch.from_numpy(arr)[None,None,...]
    t = F.interpolate(t, size=out_shape, mode="trilinear", align_corners=False)
    return t[0,0].numpy()

class TumorParamDatasetCached(Dataset):
    """
    Segmentation-only cached dataset:
    Input x: (1, D, H, W) from segm mask only
    Output y: normalized targets (Dw, rho, ...)
    """
    def __init__(self, sample_dirs, out_shape=(96,96,96), target_keys=("Dw","rho"), verbose=True):
        self.sample_dirs = sample_dirs
        self.out_shape = out_shape
        self.target_keys = target_keys

        self.cache = []
        if verbose:
            print(f"Caching {len(sample_dirs)} samples... (one-time cost)")

        for i, sd in enumerate(self.sample_dirs):
            x, y = self._load_one(sd)
            self.cache.append((x, y))
            if verbose and (i+1) % 10 == 0:
                print(f"  cached {i+1}/{len(sample_dirs)}")

        if verbose:
            print("Caching done.")

    def __len__(self):
        return len(self.cache)

    def __getitem__(self, idx):
        return self.cache[idx]

    def _load_one(self, sd):
        # ---- Targets (normalized using training stats) ----
        params = json.loads((sd/"parameters.json").read_text())

        vals = []
        for k in self.target_keys:
            v = float(params[k])
            if k == "Dw":
                v = np.log(v)  # keep your log(Dw) improvement
            vals.append(v)

        y_raw = np.array(vals, dtype=np.float32)
        y_norm = (y_raw - Y_MEAN) / Y_STD
        y = torch.tensor(y_norm, dtype=torch.float32)

        # ---- Input: segm only ----
        segm = read_nii(sd/"segm.nii.gz")
        mask = (segm > 0).astype(np.float32)

        bb = bbox_from_mask(mask > 0, margin=12)
        if bb is not None:
            mask = crop(mask, bb)

        mask = resize_3d(mask, self.out_shape)

        # (1, D, H, W)
        x = torch.from_numpy(mask[None, ...]).float()
        return x, y

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.cuda.amp import autocast, GradScaler


class CNN3DRegressor(nn.Module):
    def __init__(self, in_channels, out_dim):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv3d(in_channels, 32, 3, padding=1),
            nn.BatchNorm3d(32), nn.ReLU(inplace=True),
            nn.MaxPool3d(2),

            nn.Conv3d(32, 64, 3, padding=1),
            nn.BatchNorm3d(64), nn.ReLU(inplace=True),
            nn.MaxPool3d(2),

            nn.Conv3d(64, 128, 3, padding=1),
            nn.BatchNorm3d(128), nn.ReLU(inplace=True),
            nn.MaxPool3d(2),

            nn.Conv3d(128, 256, 3, padding=1),
            nn.BatchNorm3d(256), nn.ReLU(inplace=True),
        )
        self.head = nn.Sequential(
            nn.AdaptiveAvgPool3d(1),
            nn.Flatten(),
            nn.Linear(256, 128), nn.ReLU(inplace=True),
            nn.Dropout(0.2),
            nn.Linear(128, out_dim)
        )

    def forward(self, x):
        return self.head(self.features(x))

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device, torch.cuda.get_device_name(0) if device=="cuda" else "")

MODE = "segm"
OUT_SHAPE = (96,96,96)

# ---- Cache datasets (one-time preprocessing) ----
train_ds = TumorParamDatasetCached(train, out_shape=OUT_SHAPE, target_keys=TARGET_KEYS, verbose=True)
val_ds   = TumorParamDatasetCached(val,   out_shape=OUT_SHAPE, target_keys=TARGET_KEYS, verbose=True)

# ---- DataLoader settings ----
# With caching, workers aren't needed. Keep 0 for maximum stability.
NUM_WORKERS = 0

# Increase batch size now that IO/preprocessing is gone.
# Try 8 first; if you OOM, drop to 4.
BATCH_SIZE = 8

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

model = CNN3DRegressor(in_channels=1, out_dim=len(TARGET_KEYS)).to(device)
opt = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
scaler = GradScaler()
loss_fn = nn.MSELoss()
def mae(pred, y):
    return (pred - y).abs().mean()

EPOCHS = 300 

# ---- Best validation checkpoint ----
best_val_mse = float("inf")
best_state = None
best_epoch = -1

for epoch in range(1, EPOCHS+1):
    model.train()
    tr_loss = tr_mae = 0.0

    for x, y in train_loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        opt.zero_grad(set_to_none=True)
        with autocast():
            pred = model(x)
            loss = loss_fn(pred, y)

        scaler.scale(loss).backward()
        scaler.step(opt)
        scaler.update()

        tr_loss += loss.item()
        tr_mae  += mae(pred.detach(), y).item()

    model.eval()
    va_loss = va_mae = 0.0
    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)
            with autocast():
                pred = model(x)
                loss = loss_fn(pred, y)
            va_loss += loss.item()
            va_mae  += mae(pred, y).item()

    val_mse = va_loss / len(val_loader)

    # Save best model weights
    if val_mse < best_val_mse:
        best_val_mse = val_mse
        best_epoch = epoch
        best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    print(f"Epoch {epoch:03d} | train MSE {tr_loss/len(train_loader):.4f} MAE {tr_mae/len(train_loader):.4f} "
      f"| val MSE {val_mse:.4f} MAE {va_mae/len(val_loader):.4f} "
      f"| best val {best_val_mse:.4f} @ {best_epoch:03d}")

# Restore best model before testing
if best_state is not None:
    model.load_state_dict(best_state)
    print(f"\n✅ Loaded best model from epoch {best_epoch} with val MSE {best_val_mse:.6f}")
# Out:
# Device: cuda NVIDIA GeForce RTX 5080
# Caching 35 samples... (one-time cost)
#   cached 10/35
#   cached 20/35
#   cached 30/35
# Caching done.
# Caching 7 samples... (one-time cost)
# Caching done.
# C:\Users\Grant\AppData\Local\Temp\ipykernel_43972\2683415665.py:60: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# C:\Users\Grant\AppData\Local\Temp\ipykernel_43972\2683415665.py:81: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\Grant\AppData\Local\Temp\ipykernel_43972\2683415665.py:98: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 001 | train MSE 0.8909 MAE 0.8063 | val MSE 0.8010 MAE 0.8022 | best val 0.8010 @ 001
# Epoch 002 | train MSE 0.7412 MAE 0.7700 | val MSE 1.0373 MAE 0.8720 | best val 0.8010 @ 001
# Epoch 003 | train MSE 0.6948 MAE 0.7284 | val MSE 1.8905 MAE 1.2391 | best val 0.8010 @ 001
# Epoch 004 | train MSE 0.6935 MAE 0.7236 | val MSE 2.6260 MAE 1.5124 | best val 0.8010 @ 001
# Epoch 005 | train MSE 0.7073 MAE 0.7297 | val MSE 1.9029 MAE 1.2407 | best val 0.8010 @ 001
# Epoch 006 | train MSE 0.6588 MAE 0.6750 | val MSE 1.7268 MAE 1.1930 | best val 0.8010 @ 001
# Epoch 007 | train MSE 0.5957 MAE 0.6455 | val MSE 2.3505 MAE 1.4256 | best val 0.8010 @ 001
# Epoch 008 | train MSE 0.7192 MAE 0.6854 | val MSE 3.0079 MAE 1.6238 | best val 0.8010 @ 001
# Epoch 009 | train MSE 0.5687 MAE 0.6374 | val MSE 2.9332 MAE 1.5837 | best val 0.8010 @ 001
# Epoch 010 | train MSE 0.5661 MAE 0.6171 | val MSE 2.1943 MAE 1.3598 | best val 0.8010 @ 001
# Epoch 011 | train MSE 0.5671 MAE 0.6382 | val MSE 1.0741 MAE 0.8134 | best val 0.8010 @ 001
# Epoch 012 | train MSE 0.5977 MAE 0.6646 | val MSE 0.7490 MAE 0.7129 | best val 0.7490 @ 012
# Epoch 013 | train MSE 0.5495 MAE 0.6217 | val MSE 0.9382 MAE 0.7842 | best val 0.7490 @ 012
# Epoch 014 | train MSE 0.5646 MAE 0.6186 | val MSE 1.0881 MAE 0.9096 | best val 0.7490 @ 012
# Epoch 015 | train MSE 0.6414 MAE 0.6495 | val MSE 1.3201 MAE 1.0767 | best val 0.7490 @ 012
# Epoch 016 | train MSE 0.5645 MAE 0.6526 | val MSE 1.3374 MAE 1.0694 | best val 0.7490 @ 012
# Epoch 017 | train MSE 0.7213 MAE 0.7319 | val MSE 1.1369 MAE 0.8788 | best val 0.7490 @ 012
# Epoch 018 | train MSE 0.6428 MAE 0.6621 | val MSE 1.2279 MAE 0.9139 | best val 0.7490 @ 012
# Epoch 019 | train MSE 0.5714 MAE 0.6420 | val MSE 1.5583 MAE 0.9261 | best val 0.7490 @ 012
# Epoch 020 | train MSE 0.4946 MAE 0.5898 | val MSE 1.2479 MAE 0.8442 | best val 0.7490 @ 012
# Epoch 021 | train MSE 0.5712 MAE 0.6230 | val MSE 1.4697 MAE 1.0254 | best val 0.7490 @ 012
# Epoch 022 | train MSE 0.5913 MAE 0.6369 | val MSE 0.9045 MAE 0.7295 | best val 0.7490 @ 012
# Epoch 023 | train MSE 0.5963 MAE 0.6383 | val MSE 0.8863 MAE 0.7855 | best val 0.7490 @ 012
# Epoch 024 | train MSE 0.5536 MAE 0.6409 | val MSE 1.0281 MAE 0.8721 | best val 0.7490 @ 012
# Epoch 025 | train MSE 0.5371 MAE 0.6108 | val MSE 0.6089 MAE 0.6597 | best val 0.6089 @ 025
# Epoch 026 | train MSE 0.5729 MAE 0.6471 | val MSE 1.3828 MAE 1.0337 | best val 0.6089 @ 025
# Epoch 027 | train MSE 0.6086 MAE 0.6707 | val MSE 1.3330 MAE 1.0073 | best val 0.6089 @ 025
# Epoch 028 | train MSE 0.4623 MAE 0.5595 | val MSE 0.9649 MAE 0.7201 | best val 0.6089 @ 025
# Epoch 029 | train MSE 0.5412 MAE 0.6245 | val MSE 0.5045 MAE 0.5379 | best val 0.5045 @ 029
# Epoch 030 | train MSE 0.4804 MAE 0.5841 | val MSE 0.4669 MAE 0.5051 | best val 0.4669 @ 030
# Epoch 031 | train MSE 0.5442 MAE 0.5901 | val MSE 0.9697 MAE 0.8714 | best val 0.4669 @ 030
# Epoch 032 | train MSE 0.4291 MAE 0.5645 | val MSE 1.2093 MAE 1.0098 | best val 0.4669 @ 030
# Epoch 033 | train MSE 0.5529 MAE 0.5887 | val MSE 0.9584 MAE 0.9200 | best val 0.4669 @ 030
# Epoch 034 | train MSE 0.5147 MAE 0.6051 | val MSE 0.4659 MAE 0.5524 | best val 0.4659 @ 034
# Epoch 035 | train MSE 0.4364 MAE 0.5518 | val MSE 2.7945 MAE 1.5551 | best val 0.4659 @ 034
# Epoch 036 | train MSE 0.5077 MAE 0.6002 | val MSE 7.4771 MAE 2.6660 | best val 0.4659 @ 034
# Epoch 037 | train MSE 0.5023 MAE 0.5809 | val MSE 1.5715 MAE 0.9506 | best val 0.4659 @ 034
# Epoch 038 | train MSE 0.3250 MAE 0.4601 | val MSE 3.6032 MAE 1.6363 | best val 0.4659 @ 034
# Epoch 039 | train MSE 0.3546 MAE 0.4978 | val MSE 0.8872 MAE 0.6372 | best val 0.4659 @ 034
# Epoch 040 | train MSE 0.2586 MAE 0.4326 | val MSE 0.9240 MAE 0.8545 | best val 0.4659 @ 034
# Epoch 041 | train MSE 0.2997 MAE 0.4598 | val MSE 9.1066 MAE 2.9686 | best val 0.4659 @ 034
# Epoch 042 | train MSE 0.2077 MAE 0.3821 | val MSE 5.3763 MAE 1.7839 | best val 0.4659 @ 034
# Epoch 043 | train MSE 0.2071 MAE 0.3709 | val MSE 0.8809 MAE 0.6728 | best val 0.4659 @ 034
# Epoch 044 | train MSE 0.2712 MAE 0.3969 | val MSE 1.4146 MAE 0.9786 | best val 0.4659 @ 034
# Epoch 045 | train MSE 0.2327 MAE 0.4025 | val MSE 2.7192 MAE 1.3942 | best val 0.4659 @ 034
# Epoch 046 | train MSE 0.2416 MAE 0.4056 | val MSE 1.1764 MAE 0.9758 | best val 0.4659 @ 034
# Epoch 047 | train MSE 0.4081 MAE 0.4849 | val MSE 0.6015 MAE 0.5783 | best val 0.4659 @ 034
# Epoch 048 | train MSE 0.3998 MAE 0.4723 | val MSE 11.9110 MAE 3.2965 | best val 0.4659 @ 034
# Epoch 049 | train MSE 0.1631 MAE 0.3316 | val MSE 9.3431 MAE 3.0064 | best val 0.4659 @ 034
# Epoch 050 | train MSE 0.2584 MAE 0.4150 | val MSE 20.6763 MAE 4.5035 | best val 0.4659 @ 034
# Epoch 051 | train MSE 0.1924 MAE 0.3472 | val MSE 17.4426 MAE 4.1037 | best val 0.4659 @ 034
# Epoch 052 | train MSE 0.2423 MAE 0.3474 | val MSE 0.7735 MAE 0.6587 | best val 0.4659 @ 034
# Epoch 053 | train MSE 0.2197 MAE 0.3809 | val MSE 7.6410 MAE 2.7037 | best val 0.4659 @ 034
# Epoch 054 | train MSE 0.2018 MAE 0.3625 | val MSE 22.2031 MAE 4.6600 | best val 0.4659 @ 034
# Epoch 055 | train MSE 0.1751 MAE 0.3285 | val MSE 7.4729 MAE 2.6871 | best val 0.4659 @ 034
# Epoch 056 | train MSE 0.1768 MAE 0.3324 | val MSE 0.3168 MAE 0.4553 | best val 0.3168 @ 056
# Epoch 057 | train MSE 0.2069 MAE 0.3533 | val MSE 1.4483 MAE 1.0040 | best val 0.3168 @ 056
# Epoch 058 | train MSE 0.0984 MAE 0.2558 | val MSE 0.9058 MAE 0.8065 | best val 0.3168 @ 056
# Epoch 059 | train MSE 0.2830 MAE 0.3924 | val MSE 0.7523 MAE 0.7880 | best val 0.3168 @ 056
# Epoch 060 | train MSE 0.1583 MAE 0.3349 | val MSE 1.7544 MAE 1.1265 | best val 0.3168 @ 056
# Epoch 061 | train MSE 0.1533 MAE 0.3163 | val MSE 1.1599 MAE 0.9021 | best val 0.3168 @ 056
# Epoch 062 | train MSE 0.1586 MAE 0.3118 | val MSE 1.2597 MAE 0.9785 | best val 0.3168 @ 056
# Epoch 063 | train MSE 0.1000 MAE 0.2442 | val MSE 7.7694 MAE 2.2274 | best val 0.3168 @ 056
# Epoch 064 | train MSE 0.2024 MAE 0.3772 | val MSE 5.1618 MAE 1.9189 | best val 0.3168 @ 056
# Epoch 065 | train MSE 0.1330 MAE 0.2995 | val MSE 6.5621 MAE 2.2372 | best val 0.3168 @ 056
# Epoch 066 | train MSE 0.2538 MAE 0.4225 | val MSE 0.2361 MAE 0.3841 | best val 0.2361 @ 066
# Epoch 067 | train MSE 0.1999 MAE 0.3678 | val MSE 1.4292 MAE 0.9947 | best val 0.2361 @ 066
# Epoch 068 | train MSE 0.2937 MAE 0.4506 | val MSE 0.8278 MAE 0.7981 | best val 0.2361 @ 066
# Epoch 069 | train MSE 0.1349 MAE 0.2893 | val MSE 0.5664 MAE 0.6117 | best val 0.2361 @ 066
# Epoch 070 | train MSE 0.3932 MAE 0.4773 | val MSE 7.2634 MAE 2.6552 | best val 0.2361 @ 066
# Epoch 071 | train MSE 0.1393 MAE 0.2977 | val MSE 8.3430 MAE 2.7290 | best val 0.2361 @ 066
# Epoch 072 | train MSE 0.2771 MAE 0.4248 | val MSE 0.9203 MAE 0.7144 | best val 0.2361 @ 066
# Epoch 073 | train MSE 0.1152 MAE 0.2670 | val MSE 1.0627 MAE 0.6687 | best val 0.2361 @ 066
# Epoch 074 | train MSE 0.1936 MAE 0.3595 | val MSE 0.4484 MAE 0.4354 | best val 0.2361 @ 066
# Epoch 075 | train MSE 0.2744 MAE 0.3879 | val MSE 2.0580 MAE 1.2290 | best val 0.2361 @ 066
# Epoch 076 | train MSE 0.3081 MAE 0.4614 | val MSE 12.8493 MAE 3.5464 | best val 0.2361 @ 066
# Epoch 077 | train MSE 0.2620 MAE 0.4273 | val MSE 28.5243 MAE 5.1437 | best val 0.2361 @ 066
# Epoch 078 | train MSE 0.2125 MAE 0.3736 | val MSE 6.7860 MAE 2.3060 | best val 0.2361 @ 066
# Epoch 079 | train MSE 0.2921 MAE 0.4065 | val MSE 3.5150 MAE 1.7507 | best val 0.2361 @ 066
# Epoch 080 | train MSE 0.1460 MAE 0.3237 | val MSE 1.8001 MAE 1.0021 | best val 0.2361 @ 066
# Epoch 081 | train MSE 0.1091 MAE 0.2560 | val MSE 0.8599 MAE 0.7900 | best val 0.2361 @ 066
# Epoch 082 | train MSE 0.1742 MAE 0.3278 | val MSE 1.6648 MAE 1.2004 | best val 0.2361 @ 066
# Epoch 083 | train MSE 0.2785 MAE 0.4186 | val MSE 1.0877 MAE 0.8934 | best val 0.2361 @ 066
# Epoch 084 | train MSE 0.1068 MAE 0.2620 | val MSE 8.4881 MAE 2.6892 | best val 0.2361 @ 066
# Epoch 085 | train MSE 0.1466 MAE 0.2973 | val MSE 2.5030 MAE 1.1713 | best val 0.2361 @ 066
# Epoch 086 | train MSE 0.1134 MAE 0.2635 | val MSE 0.8766 MAE 0.8592 | best val 0.2361 @ 066
# Epoch 087 | train MSE 0.1713 MAE 0.3271 | val MSE 0.7634 MAE 0.8076 | best val 0.2361 @ 066
# Epoch 088 | train MSE 0.1170 MAE 0.2784 | val MSE 0.6338 MAE 0.7060 | best val 0.2361 @ 066
# Epoch 089 | train MSE 0.1235 MAE 0.2796 | val MSE 1.2067 MAE 0.8588 | best val 0.2361 @ 066
# Epoch 090 | train MSE 0.0877 MAE 0.2370 | val MSE 0.2293 MAE 0.3438 | best val 0.2293 @ 090
# Epoch 091 | train MSE 0.0896 MAE 0.2406 | val MSE 0.7374 MAE 0.6720 | best val 0.2293 @ 090
# Epoch 092 | train MSE 0.1191 MAE 0.2634 | val MSE 2.8941 MAE 1.6064 | best val 0.2293 @ 090
# Epoch 093 | train MSE 0.0719 MAE 0.2137 | val MSE 0.4792 MAE 0.6511 | best val 0.2293 @ 090
# Epoch 094 | train MSE 0.1480 MAE 0.3131 | val MSE 0.7553 MAE 0.5827 | best val 0.2293 @ 090
# Epoch 095 | train MSE 0.0582 MAE 0.1962 | val MSE 0.5750 MAE 0.5240 | best val 0.2293 @ 090
# Epoch 096 | train MSE 0.1226 MAE 0.2951 | val MSE 1.3047 MAE 0.9546 | best val 0.2293 @ 090
# Epoch 097 | train MSE 0.1612 MAE 0.3326 | val MSE 1.9261 MAE 1.2773 | best val 0.2293 @ 090
# Epoch 098 | train MSE 0.1233 MAE 0.2653 | val MSE 0.4498 MAE 0.5551 | best val 0.2293 @ 090
# Epoch 099 | train MSE 0.2610 MAE 0.3684 | val MSE 1.2644 MAE 0.8386 | best val 0.2293 @ 090
# Epoch 100 | train MSE 0.1460 MAE 0.3058 | val MSE 0.8606 MAE 0.6264 | best val 0.2293 @ 090
# Epoch 101 | train MSE 0.1839 MAE 0.3476 | val MSE 4.8002 MAE 1.6818 | best val 0.2293 @ 090
# Epoch 102 | train MSE 0.0856 MAE 0.2362 | val MSE 0.9874 MAE 0.6762 | best val 0.2293 @ 090
# Epoch 103 | train MSE 0.1181 MAE 0.2671 | val MSE 1.4723 MAE 1.0931 | best val 0.2293 @ 090
# Epoch 104 | train MSE 0.1244 MAE 0.2827 | val MSE 2.0926 MAE 1.1012 | best val 0.2293 @ 090
# Epoch 105 | train MSE 0.1664 MAE 0.3474 | val MSE 2.0643 MAE 1.1387 | best val 0.2293 @ 090
# Epoch 106 | train MSE 0.0817 MAE 0.2249 | val MSE 2.2615 MAE 1.2425 | best val 0.2293 @ 090
# Epoch 107 | train MSE 0.1428 MAE 0.3097 | val MSE 1.2276 MAE 0.8475 | best val 0.2293 @ 090
# Epoch 108 | train MSE 0.0752 MAE 0.2219 | val MSE 0.5497 MAE 0.5091 | best val 0.2293 @ 090
# Epoch 109 | train MSE 0.1219 MAE 0.2834 | val MSE 0.3399 MAE 0.4427 | best val 0.2293 @ 090
# Epoch 110 | train MSE 0.0849 MAE 0.2319 | val MSE 0.4484 MAE 0.6402 | best val 0.2293 @ 090
# Epoch 111 | train MSE 0.0997 MAE 0.2579 | val MSE 0.4071 MAE 0.6012 | best val 0.2293 @ 090
# Epoch 112 | train MSE 0.1598 MAE 0.3133 | val MSE 0.3391 MAE 0.4246 | best val 0.2293 @ 090
# Epoch 113 | train MSE 0.1963 MAE 0.3387 | val MSE 0.3105 MAE 0.4610 | best val 0.2293 @ 090
# Epoch 114 | train MSE 0.1533 MAE 0.2994 | val MSE 9.0819 MAE 2.9329 | best val 0.2293 @ 090
# Epoch 115 | train MSE 0.2192 MAE 0.3918 | val MSE 5.0822 MAE 2.0936 | best val 0.2293 @ 090
# Epoch 116 | train MSE 0.1057 MAE 0.2531 | val MSE 0.7020 MAE 0.7122 | best val 0.2293 @ 090
# Epoch 117 | train MSE 0.1444 MAE 0.3115 | val MSE 1.8848 MAE 1.1755 | best val 0.2293 @ 090
# Epoch 118 | train MSE 0.1680 MAE 0.3086 | val MSE 1.1599 MAE 0.9736 | best val 0.2293 @ 090
# Epoch 119 | train MSE 0.1831 MAE 0.3420 | val MSE 2.4219 MAE 1.3511 | best val 0.2293 @ 090
# Epoch 120 | train MSE 0.1279 MAE 0.3055 | val MSE 0.9222 MAE 0.7353 | best val 0.2293 @ 090
# Epoch 121 | train MSE 0.0983 MAE 0.2429 | val MSE 2.7952 MAE 1.5944 | best val 0.2293 @ 090
# Epoch 122 | train MSE 0.1380 MAE 0.2980 | val MSE 5.2797 MAE 2.2358 | best val 0.2293 @ 090
# Epoch 123 | train MSE 0.1573 MAE 0.3360 | val MSE 3.5886 MAE 1.8229 | best val 0.2293 @ 090
# Epoch 124 | train MSE 0.0659 MAE 0.2066 | val MSE 0.9950 MAE 0.8908 | best val 0.2293 @ 090
# Epoch 125 | train MSE 0.1081 MAE 0.2565 | val MSE 1.8547 MAE 1.2198 | best val 0.2293 @ 090
# Epoch 126 | train MSE 0.4096 MAE 0.4135 | val MSE 1.6164 MAE 1.1597 | best val 0.2293 @ 090
# Epoch 127 | train MSE 0.1191 MAE 0.2915 | val MSE 2.7275 MAE 1.4105 | best val 0.2293 @ 090
# Epoch 128 | train MSE 0.0734 MAE 0.2162 | val MSE 1.7254 MAE 0.9245 | best val 0.2293 @ 090
# Epoch 129 | train MSE 0.1031 MAE 0.2679 | val MSE 2.8311 MAE 1.5053 | best val 0.2293 @ 090
# Epoch 130 | train MSE 0.1061 MAE 0.2627 | val MSE 1.1922 MAE 0.9852 | best val 0.2293 @ 090
# Epoch 131 | train MSE 0.1791 MAE 0.3393 | val MSE 0.9654 MAE 0.6896 | best val 0.2293 @ 090
# Epoch 132 | train MSE 0.0901 MAE 0.2358 | val MSE 0.5296 MAE 0.5976 | best val 0.2293 @ 090
# Epoch 133 | train MSE 0.0658 MAE 0.2108 | val MSE 0.9325 MAE 0.7377 | best val 0.2293 @ 090
# Epoch 134 | train MSE 0.1619 MAE 0.3408 | val MSE 2.9389 MAE 1.4672 | best val 0.2293 @ 090
# Epoch 135 | train MSE 0.2265 MAE 0.3635 | val MSE 6.8235 MAE 2.3886 | best val 0.2293 @ 090
# Epoch 136 | train MSE 0.0907 MAE 0.2494 | val MSE 3.3183 MAE 1.5080 | best val 0.2293 @ 090
# Epoch 137 | train MSE 0.1197 MAE 0.2686 | val MSE 2.3263 MAE 1.2133 | best val 0.2293 @ 090
# Epoch 138 | train MSE 0.0588 MAE 0.1876 | val MSE 0.5443 MAE 0.5989 | best val 0.2293 @ 090
# Epoch 139 | train MSE 0.0931 MAE 0.2480 | val MSE 1.5773 MAE 1.0960 | best val 0.2293 @ 090
# Epoch 140 | train MSE 0.1291 MAE 0.2752 | val MSE 3.4350 MAE 1.7436 | best val 0.2293 @ 090
# Epoch 141 | train MSE 0.0586 MAE 0.1962 | val MSE 2.5647 MAE 1.4978 | best val 0.2293 @ 090
# Epoch 142 | train MSE 0.1118 MAE 0.2793 | val MSE 2.5768 MAE 1.4864 | best val 0.2293 @ 090
# Epoch 143 | train MSE 0.1863 MAE 0.3428 | val MSE 5.2918 MAE 2.1900 | best val 0.2293 @ 090
# Epoch 144 | train MSE 0.1176 MAE 0.2907 | val MSE 5.5638 MAE 2.3036 | best val 0.2293 @ 090
# Epoch 145 | train MSE 0.1184 MAE 0.2774 | val MSE 1.3621 MAE 0.9979 | best val 0.2293 @ 090
# Epoch 146 | train MSE 0.1498 MAE 0.3080 | val MSE 0.7497 MAE 0.7235 | best val 0.2293 @ 090
# Epoch 147 | train MSE 0.1003 MAE 0.2723 | val MSE 1.2288 MAE 0.9512 | best val 0.2293 @ 090
# Epoch 148 | train MSE 0.1350 MAE 0.2937 | val MSE 0.7885 MAE 0.7835 | best val 0.2293 @ 090
# Epoch 149 | train MSE 0.0971 MAE 0.2396 | val MSE 0.4317 MAE 0.5200 | best val 0.2293 @ 090
# Epoch 150 | train MSE 0.1401 MAE 0.2900 | val MSE 0.6357 MAE 0.6550 | best val 0.2293 @ 090
# Epoch 151 | train MSE 0.2030 MAE 0.3305 | val MSE 1.1137 MAE 0.9021 | best val 0.2293 @ 090
# Epoch 152 | train MSE 0.1283 MAE 0.2974 | val MSE 1.6628 MAE 1.0769 | best val 0.2293 @ 090
# Epoch 153 | train MSE 0.3014 MAE 0.4126 | val MSE 1.6921 MAE 1.2155 | best val 0.2293 @ 090
# Epoch 154 | train MSE 0.1883 MAE 0.3410 | val MSE 10.2958 MAE 3.1775 | best val 0.2293 @ 090
# Epoch 155 | train MSE 0.1084 MAE 0.2686 | val MSE 2.7037 MAE 1.4689 | best val 0.2293 @ 090
# Epoch 156 | train MSE 0.1423 MAE 0.2970 | val MSE 0.3584 MAE 0.4724 | best val 0.2293 @ 090
# Epoch 157 | train MSE 0.1216 MAE 0.2934 | val MSE 0.7686 MAE 0.8228 | best val 0.2293 @ 090
# Epoch 158 | train MSE 0.1220 MAE 0.2867 | val MSE 1.2935 MAE 0.9960 | best val 0.2293 @ 090
# Epoch 159 | train MSE 0.1165 MAE 0.2786 | val MSE 1.8633 MAE 0.9690 | best val 0.2293 @ 090
# Epoch 160 | train MSE 0.1302 MAE 0.2966 | val MSE 6.0496 MAE 2.3023 | best val 0.2293 @ 090
# Epoch 161 | train MSE 0.0564 MAE 0.1962 | val MSE 6.0898 MAE 2.1839 | best val 0.2293 @ 090
# Epoch 162 | train MSE 0.1787 MAE 0.3175 | val MSE 1.7617 MAE 1.0463 | best val 0.2293 @ 090
# Epoch 163 | train MSE 0.0943 MAE 0.2621 | val MSE 0.5428 MAE 0.6839 | best val 0.2293 @ 090
# Epoch 164 | train MSE 0.0865 MAE 0.2282 | val MSE 0.7844 MAE 0.7355 | best val 0.2293 @ 090
# Epoch 165 | train MSE 0.0936 MAE 0.2407 | val MSE 0.5388 MAE 0.6926 | best val 0.2293 @ 090
# Epoch 166 | train MSE 0.1097 MAE 0.2833 | val MSE 0.2338 MAE 0.4125 | best val 0.2293 @ 090
# Epoch 167 | train MSE 0.2113 MAE 0.3382 | val MSE 1.5276 MAE 1.1496 | best val 0.2293 @ 090
# Epoch 168 | train MSE 0.1016 MAE 0.2594 | val MSE 1.3594 MAE 0.9929 | best val 0.2293 @ 090
# Epoch 169 | train MSE 0.1856 MAE 0.3346 | val MSE 0.2377 MAE 0.3714 | best val 0.2293 @ 090
# Epoch 170 | train MSE 0.1175 MAE 0.2744 | val MSE 1.6714 MAE 1.1486 | best val 0.2293 @ 090
# Epoch 171 | train MSE 0.1227 MAE 0.2928 | val MSE 0.3270 MAE 0.5096 | best val 0.2293 @ 090
# Epoch 172 | train MSE 0.0943 MAE 0.2441 | val MSE 1.6946 MAE 1.1630 | best val 0.2293 @ 090
# Epoch 173 | train MSE 0.1014 MAE 0.2633 | val MSE 0.2860 MAE 0.4581 | best val 0.2293 @ 090
# Epoch 174 | train MSE 0.2378 MAE 0.3868 | val MSE 0.1475 MAE 0.2941 | best val 0.1475 @ 174
# Epoch 175 | train MSE 0.1470 MAE 0.3220 | val MSE 0.1726 MAE 0.3118 | best val 0.1475 @ 174
# Epoch 176 | train MSE 0.2489 MAE 0.3771 | val MSE 0.2492 MAE 0.3120 | best val 0.1475 @ 174
# Epoch 177 | train MSE 0.1297 MAE 0.3019 | val MSE 2.8758 MAE 1.5260 | best val 0.1475 @ 174
# Epoch 178 | train MSE 0.1207 MAE 0.3041 | val MSE 0.3150 MAE 0.4336 | best val 0.1475 @ 174
# Epoch 179 | train MSE 0.3330 MAE 0.4401 | val MSE 0.3450 MAE 0.3853 | best val 0.1475 @ 174
# Epoch 180 | train MSE 0.0777 MAE 0.2333 | val MSE 2.6174 MAE 1.4816 | best val 0.1475 @ 174
# Epoch 181 | train MSE 0.1196 MAE 0.2661 | val MSE 4.2634 MAE 1.9549 | best val 0.1475 @ 174
# Epoch 182 | train MSE 0.0617 MAE 0.1939 | val MSE 2.8355 MAE 1.5305 | best val 0.1475 @ 174
# Epoch 183 | train MSE 0.1947 MAE 0.3356 | val MSE 0.3289 MAE 0.5045 | best val 0.1475 @ 174
# Epoch 184 | train MSE 0.0770 MAE 0.2401 | val MSE 1.1739 MAE 0.8658 | best val 0.1475 @ 174
# Epoch 185 | train MSE 0.1864 MAE 0.3428 | val MSE 0.4298 MAE 0.4869 | best val 0.1475 @ 174
# Epoch 186 | train MSE 0.0804 MAE 0.2109 | val MSE 1.9952 MAE 1.2947 | best val 0.1475 @ 174
# Epoch 187 | train MSE 0.0805 MAE 0.2363 | val MSE 3.5873 MAE 1.8080 | best val 0.1475 @ 174
# Epoch 188 | train MSE 0.3017 MAE 0.3756 | val MSE 1.8445 MAE 1.1993 | best val 0.1475 @ 174
# Epoch 189 | train MSE 0.0752 MAE 0.2219 | val MSE 0.4694 MAE 0.6384 | best val 0.1475 @ 174
# Epoch 190 | train MSE 0.1920 MAE 0.3742 | val MSE 0.8875 MAE 0.6119 | best val 0.1475 @ 174
# Epoch 191 | train MSE 0.2088 MAE 0.3746 | val MSE 0.8237 MAE 0.6508 | best val 0.1475 @ 174
# Epoch 192 | train MSE 0.1038 MAE 0.2585 | val MSE 0.7139 MAE 0.7906 | best val 0.1475 @ 174
# Epoch 193 | train MSE 0.1695 MAE 0.3335 | val MSE 1.5950 MAE 1.0050 | best val 0.1475 @ 174
# Epoch 194 | train MSE 0.0996 MAE 0.2452 | val MSE 0.5023 MAE 0.6551 | best val 0.1475 @ 174
# Epoch 195 | train MSE 0.1432 MAE 0.3079 | val MSE 1.1063 MAE 0.9245 | best val 0.1475 @ 174
# Epoch 196 | train MSE 0.1430 MAE 0.3041 | val MSE 0.6186 MAE 0.6670 | best val 0.1475 @ 174
# Epoch 197 | train MSE 0.0812 MAE 0.2442 | val MSE 0.8720 MAE 0.8387 | best val 0.1475 @ 174
# Epoch 198 | train MSE 0.1389 MAE 0.2920 | val MSE 0.8807 MAE 0.8761 | best val 0.1475 @ 174
# Epoch 199 | train MSE 0.1028 MAE 0.2583 | val MSE 0.2653 MAE 0.4737 | best val 0.1475 @ 174
# Epoch 200 | train MSE 0.0927 MAE 0.2382 | val MSE 0.2312 MAE 0.4231 | best val 0.1475 @ 174
# Epoch 201 | train MSE 0.1179 MAE 0.2862 | val MSE 0.7808 MAE 0.6705 | best val 0.1475 @ 174
# Epoch 202 | train MSE 0.0571 MAE 0.1861 | val MSE 0.8571 MAE 0.6612 | best val 0.1475 @ 174
# Epoch 203 | train MSE 0.1482 MAE 0.2999 | val MSE 0.3721 MAE 0.5145 | best val 0.1475 @ 174
# Epoch 204 | train MSE 0.1143 MAE 0.2675 | val MSE 0.4666 MAE 0.5574 | best val 0.1475 @ 174
# Epoch 205 | train MSE 0.0964 MAE 0.2535 | val MSE 0.2819 MAE 0.4660 | best val 0.1475 @ 174
# Epoch 206 | train MSE 0.1153 MAE 0.2804 | val MSE 1.9634 MAE 1.0229 | best val 0.1475 @ 174
# Epoch 207 | train MSE 0.1163 MAE 0.2845 | val MSE 1.0065 MAE 0.8203 | best val 0.1475 @ 174
# Epoch 208 | train MSE 0.0721 MAE 0.2252 | val MSE 1.3710 MAE 1.0863 | best val 0.1475 @ 174
# Epoch 209 | train MSE 0.0494 MAE 0.1716 | val MSE 0.7154 MAE 0.7442 | best val 0.1475 @ 174
# Epoch 210 | train MSE 0.0407 MAE 0.1745 | val MSE 1.0578 MAE 0.7161 | best val 0.1475 @ 174
# Epoch 211 | train MSE 0.0615 MAE 0.2119 | val MSE 0.4530 MAE 0.5039 | best val 0.1475 @ 174
# Epoch 212 | train MSE 0.0856 MAE 0.2499 | val MSE 0.2250 MAE 0.4177 | best val 0.1475 @ 174
# Epoch 213 | train MSE 0.0439 MAE 0.1677 | val MSE 0.8898 MAE 0.8802 | best val 0.1475 @ 174
# Epoch 214 | train MSE 0.1199 MAE 0.2615 | val MSE 1.2687 MAE 0.9329 | best val 0.1475 @ 174
# Epoch 215 | train MSE 0.0935 MAE 0.2410 | val MSE 0.9178 MAE 0.8285 | best val 0.1475 @ 174
# Epoch 216 | train MSE 0.0642 MAE 0.1955 | val MSE 0.4086 MAE 0.5016 | best val 0.1475 @ 174
# Epoch 217 | train MSE 0.0874 MAE 0.2423 | val MSE 0.2107 MAE 0.3690 | best val 0.1475 @ 174
# Epoch 218 | train MSE 0.1425 MAE 0.3210 | val MSE 0.2633 MAE 0.4268 | best val 0.1475 @ 174
# Epoch 219 | train MSE 0.1617 MAE 0.3202 | val MSE 0.2492 MAE 0.4153 | best val 0.1475 @ 174
# Epoch 220 | train MSE 0.1381 MAE 0.2680 | val MSE 0.5970 MAE 0.5680 | best val 0.1475 @ 174
# Epoch 221 | train MSE 0.1259 MAE 0.2725 | val MSE 3.8606 MAE 1.8512 | best val 0.1475 @ 174
# Epoch 222 | train MSE 0.1572 MAE 0.3354 | val MSE 3.4693 MAE 1.7589 | best val 0.1475 @ 174
# Epoch 223 | train MSE 0.1040 MAE 0.2674 | val MSE 0.9274 MAE 0.6857 | best val 0.1475 @ 174
# Epoch 224 | train MSE 0.1543 MAE 0.3363 | val MSE 0.3046 MAE 0.5070 | best val 0.1475 @ 174
# Epoch 225 | train MSE 0.0719 MAE 0.2141 | val MSE 0.7586 MAE 0.7570 | best val 0.1475 @ 174
# Epoch 226 | train MSE 0.0785 MAE 0.2332 | val MSE 1.6657 MAE 1.1915 | best val 0.1475 @ 174
# Epoch 227 | train MSE 0.0792 MAE 0.2131 | val MSE 1.3671 MAE 0.9841 | best val 0.1475 @ 174
# Epoch 228 | train MSE 0.1799 MAE 0.3377 | val MSE 0.3587 MAE 0.5629 | best val 0.1475 @ 174
# Epoch 229 | train MSE 0.1555 MAE 0.3159 | val MSE 0.7953 MAE 0.6396 | best val 0.1475 @ 174
# Epoch 230 | train MSE 0.0932 MAE 0.2279 | val MSE 0.3992 MAE 0.4314 | best val 0.1475 @ 174
# Epoch 231 | train MSE 0.0942 MAE 0.2332 | val MSE 0.5659 MAE 0.6319 | best val 0.1475 @ 174
# Epoch 232 | train MSE 0.1274 MAE 0.2824 | val MSE 1.3120 MAE 0.8816 | best val 0.1475 @ 174
# Epoch 233 | train MSE 0.0642 MAE 0.1977 | val MSE 2.8953 MAE 1.6183 | best val 0.1475 @ 174
# Epoch 234 | train MSE 0.0929 MAE 0.2512 | val MSE 2.7215 MAE 1.5570 | best val 0.1475 @ 174
# Epoch 235 | train MSE 0.1253 MAE 0.2808 | val MSE 0.4485 MAE 0.5940 | best val 0.1475 @ 174
# Epoch 236 | train MSE 0.0897 MAE 0.2362 | val MSE 0.9250 MAE 0.8754 | best val 0.1475 @ 174
# Epoch 237 | train MSE 0.1423 MAE 0.3106 | val MSE 3.6727 MAE 1.7871 | best val 0.1475 @ 174
# Epoch 238 | train MSE 0.2032 MAE 0.3459 | val MSE 1.5189 MAE 1.0234 | best val 0.1475 @ 174
# Epoch 239 | train MSE 0.1050 MAE 0.2443 | val MSE 1.9770 MAE 1.2048 | best val 0.1475 @ 174
# Epoch 240 | train MSE 0.1861 MAE 0.3334 | val MSE 2.0332 MAE 1.2324 | best val 0.1475 @ 174
# Epoch 241 | train MSE 0.1697 MAE 0.3210 | val MSE 0.6977 MAE 0.7489 | best val 0.1475 @ 174
# Epoch 242 | train MSE 0.1028 MAE 0.2477 | val MSE 3.2610 MAE 1.5989 | best val 0.1475 @ 174
# Epoch 243 | train MSE 0.1324 MAE 0.2892 | val MSE 4.0610 MAE 1.8690 | best val 0.1475 @ 174
# Epoch 244 | train MSE 0.0780 MAE 0.2363 | val MSE 1.1950 MAE 1.0115 | best val 0.1475 @ 174
# Epoch 245 | train MSE 0.1038 MAE 0.2483 | val MSE 0.3251 MAE 0.5062 | best val 0.1475 @ 174
# Epoch 246 | train MSE 0.0840 MAE 0.2251 | val MSE 0.5754 MAE 0.6665 | best val 0.1475 @ 174
# Epoch 247 | train MSE 0.0761 MAE 0.2209 | val MSE 0.2458 MAE 0.4216 | best val 0.1475 @ 174
# Epoch 248 | train MSE 0.0874 MAE 0.2293 | val MSE 0.7670 MAE 0.8148 | best val 0.1475 @ 174
# Epoch 249 | train MSE 0.1567 MAE 0.3002 | val MSE 0.6995 MAE 0.6922 | best val 0.1475 @ 174
# Epoch 250 | train MSE 0.0454 MAE 0.1623 | val MSE 0.5827 MAE 0.5593 | best val 0.1475 @ 174
# Epoch 251 | train MSE 0.2275 MAE 0.3499 | val MSE 0.9859 MAE 0.7405 | best val 0.1475 @ 174
# Epoch 252 | train MSE 0.1489 MAE 0.3067 | val MSE 2.0806 MAE 1.2852 | best val 0.1475 @ 174
# Epoch 253 | train MSE 0.0832 MAE 0.2314 | val MSE 2.1107 MAE 1.1808 | best val 0.1475 @ 174
# Epoch 254 | train MSE 0.0897 MAE 0.2576 | val MSE 0.3532 MAE 0.5136 | best val 0.1475 @ 174
# Epoch 255 | train MSE 0.2421 MAE 0.4293 | val MSE 2.1607 MAE 1.3436 | best val 0.1475 @ 174
# Epoch 256 | train MSE 0.1188 MAE 0.2699 | val MSE 3.4050 MAE 1.5271 | best val 0.1475 @ 174
# Epoch 257 | train MSE 0.0968 MAE 0.2457 | val MSE 1.7657 MAE 1.0370 | best val 0.1475 @ 174
# Epoch 258 | train MSE 0.0646 MAE 0.1954 | val MSE 0.8497 MAE 0.8010 | best val 0.1475 @ 174
# Epoch 259 | train MSE 0.0793 MAE 0.2339 | val MSE 0.2759 MAE 0.3970 | best val 0.1475 @ 174
# Epoch 260 | train MSE 0.0624 MAE 0.1977 | val MSE 1.3777 MAE 0.9674 | best val 0.1475 @ 174
# Epoch 261 | train MSE 0.1037 MAE 0.2699 | val MSE 0.2800 MAE 0.4414 | best val 0.1475 @ 174
# Epoch 262 | train MSE 0.2641 MAE 0.3622 | val MSE 2.0587 MAE 1.3284 | best val 0.1475 @ 174
# Epoch 263 | train MSE 0.1668 MAE 0.3282 | val MSE 2.0168 MAE 1.2871 | best val 0.1475 @ 174
# Epoch 264 | train MSE 0.1614 MAE 0.3295 | val MSE 0.8177 MAE 0.7243 | best val 0.1475 @ 174
# Epoch 265 | train MSE 0.1530 MAE 0.3314 | val MSE 0.1777 MAE 0.3445 | best val 0.1475 @ 174
# Epoch 266 | train MSE 0.1289 MAE 0.2947 | val MSE 0.3605 MAE 0.4339 | best val 0.1475 @ 174
# Epoch 267 | train MSE 0.0777 MAE 0.2186 | val MSE 0.6459 MAE 0.7586 | best val 0.1475 @ 174
# Epoch 268 | train MSE 0.0672 MAE 0.2101 | val MSE 0.5472 MAE 0.6258 | best val 0.1475 @ 174
# Epoch 269 | train MSE 0.1188 MAE 0.2766 | val MSE 0.8648 MAE 0.6508 | best val 0.1475 @ 174
# Epoch 270 | train MSE 0.0938 MAE 0.2542 | val MSE 2.4911 MAE 1.4614 | best val 0.1475 @ 174
# Epoch 271 | train MSE 0.0715 MAE 0.2151 | val MSE 2.6261 MAE 1.5229 | best val 0.1475 @ 174
# Epoch 272 | train MSE 0.0538 MAE 0.1928 | val MSE 1.1614 MAE 0.9631 | best val 0.1475 @ 174
# Epoch 273 | train MSE 0.1229 MAE 0.2432 | val MSE 0.2582 MAE 0.3724 | best val 0.1475 @ 174
# Epoch 274 | train MSE 0.1230 MAE 0.2889 | val MSE 1.0132 MAE 0.8127 | best val 0.1475 @ 174
# Epoch 275 | train MSE 0.0592 MAE 0.1924 | val MSE 0.6733 MAE 0.6520 | best val 0.1475 @ 174
# Epoch 276 | train MSE 0.0657 MAE 0.2062 | val MSE 1.1866 MAE 0.7886 | best val 0.1475 @ 174
# Epoch 277 | train MSE 0.0375 MAE 0.1471 | val MSE 0.5538 MAE 0.5619 | best val 0.1475 @ 174
# Epoch 278 | train MSE 0.0636 MAE 0.2195 | val MSE 0.7431 MAE 0.8168 | best val 0.1475 @ 174
# Epoch 279 | train MSE 0.1015 MAE 0.2608 | val MSE 1.4595 MAE 1.1264 | best val 0.1475 @ 174
# Epoch 280 | train MSE 0.0460 MAE 0.1776 | val MSE 2.9202 MAE 1.6178 | best val 0.1475 @ 174
# Epoch 281 | train MSE 0.1154 MAE 0.2543 | val MSE 2.1193 MAE 1.0433 | best val 0.1475 @ 174
# Epoch 282 | train MSE 0.1396 MAE 0.3172 | val MSE 0.3381 MAE 0.4928 | best val 0.1475 @ 174
# Epoch 283 | train MSE 0.0837 MAE 0.2314 | val MSE 0.4425 MAE 0.5341 | best val 0.1475 @ 174
# Epoch 284 | train MSE 0.0838 MAE 0.2274 | val MSE 2.1629 MAE 1.3673 | best val 0.1475 @ 174
# Epoch 285 | train MSE 0.1090 MAE 0.2758 | val MSE 1.7770 MAE 1.2466 | best val 0.1475 @ 174
# Epoch 286 | train MSE 0.1661 MAE 0.3370 | val MSE 0.1349 MAE 0.2933 | best val 0.1349 @ 286
# Epoch 287 | train MSE 0.0633 MAE 0.2025 | val MSE 0.2183 MAE 0.3584 | best val 0.1349 @ 286
# Epoch 288 | train MSE 0.0782 MAE 0.2215 | val MSE 0.3363 MAE 0.5102 | best val 0.1349 @ 286
# Epoch 289 | train MSE 0.1065 MAE 0.2681 | val MSE 0.8577 MAE 0.8675 | best val 0.1349 @ 286
# Epoch 290 | train MSE 0.1504 MAE 0.3240 | val MSE 0.2509 MAE 0.4347 | best val 0.1349 @ 286
# Epoch 291 | train MSE 0.0658 MAE 0.2004 | val MSE 2.1387 MAE 1.3598 | best val 0.1349 @ 286
# Epoch 292 | train MSE 0.0899 MAE 0.2474 | val MSE 1.3866 MAE 1.0310 | best val 0.1349 @ 286
# Epoch 293 | train MSE 0.0654 MAE 0.2019 | val MSE 0.4287 MAE 0.4896 | best val 0.1349 @ 286
# Epoch 294 | train MSE 0.0614 MAE 0.2102 | val MSE 0.4548 MAE 0.4827 | best val 0.1349 @ 286
# Epoch 295 | train MSE 0.1116 MAE 0.2892 | val MSE 0.9407 MAE 0.8046 | best val 0.1349 @ 286
# Epoch 296 | train MSE 0.0731 MAE 0.2166 | val MSE 2.3022 MAE 1.1883 | best val 0.1349 @ 286
# Epoch 297 | train MSE 0.0867 MAE 0.2375 | val MSE 0.3873 MAE 0.5371 | best val 0.1349 @ 286
# Epoch 298 | train MSE 0.1761 MAE 0.3483 | val MSE 0.2513 MAE 0.3966 | best val 0.1349 @ 286
# Epoch 299 | train MSE 0.1130 MAE 0.2688 | val MSE 0.4849 MAE 0.6086 | best val 0.1349 @ 286
# Epoch 300 | train MSE 0.0752 MAE 0.2075 | val MSE 2.0211 MAE 1.3248 | best val 0.1349 @ 286
#
# ✅ Loaded best model from epoch 286 with val MSE 0.134900

# %%
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torch

test_ds = TumorParamDatasetCached(test, out_shape=OUT_SHAPE, target_keys=TARGET_KEYS, verbose=True)
test_loader = DataLoader(test_ds, batch_size=1, shuffle=False, num_workers=0, pin_memory=True)

model.eval()
preds_norm, trues_norm = [], []
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device, non_blocking=True)
        pred = model(x).cpu().numpy()[0]
        preds_norm.append(pred)
        trues_norm.append(y.numpy()[0])

preds_norm = np.array(preds_norm)
trues_norm = np.array(trues_norm)

# Denormalize back to original parameter scale
preds = preds_norm * Y_STD + Y_MEAN
trues = trues_norm * Y_STD + Y_MEAN

# If Dw was trained in log-space, convert it back
for i, k in enumerate(TARGET_KEYS):
    if k == "Dw":
        preds[:, i] = np.exp(preds[:, i])
        trues[:, i] = np.exp(trues[:, i])

for i,k in enumerate(TARGET_KEYS):
    mae_i = np.abs(preds[:,i] - trues[:,i]).mean()
    rmse_i = np.sqrt(((preds[:,i] - trues[:,i])**2).mean())
    print(f"{k}: MAE={mae_i:.6f} RMSE={rmse_i:.6f}")

for i,k in enumerate(TARGET_KEYS):
    plt.figure()
    plt.scatter(trues[:,i], preds[:,i])
    mn = min(trues[:,i].min(), preds[:,i].min())
    mx = max(trues[:,i].max(), preds[:,i].max())
    plt.plot([mn,mx],[mn,mx])
    plt.xlabel("True")
    plt.ylabel("Predicted")
    plt.title(f"{k}: Predicted vs True")
    plt.show()
# Out:
# Caching 8 samples... (one-time cost)
# Caching done.
# Dw: MAE=0.543562 RMSE=0.611890
# rho: MAE=0.052855 RMSE=0.056799

# %%
import torch

torch.save({
    "model_state": model.state_dict(),
    "target_keys": TARGET_KEYS,
    "mode": MODE,
    "out_shape": OUT_SHAPE,
    "y_mean": Y_MEAN,
    "y_std": Y_STD,
}, "dcnn_param_model.pt")

print("Saved -> dcnn_param_model.pt")
# Out:
# Saved -> dcnn_param_model.pt
