# %%
from pathlib import Path
import json

DATA_ROOT = Path("synthetic_runs1T_FK_2c")  # 250-patient dataset

samples = sorted([p for p in DATA_ROOT.glob("synthetic1T_run*") if p.is_dir()])
print("DATA_ROOT exists:", DATA_ROOT.exists())
print("Num samples:", len(samples))
print("First sample:", samples[0] if samples else None)

params = json.loads((samples[0] / "parameters.json").read_text())
print("Parameter keys:", list(params.keys()))
print("Example params:", {k: params[k] for k in ("Dw", "rho")})
# Out:
# DATA_ROOT exists: True
# Num samples: 250
# First sample: synthetic_runs1T_FK_2c\synthetic1T_run100
# Parameter keys: ['th_necro_n', 'th_enhancing_p', 'th_edema_p', 'Dw', 'rho', 'lambda_np', 'sigma_np', 'D_s', 'lambda_s', 'gm_path', 'wm_path', 'NxT1_pct', 'NyT1_pct', 'NzT1_pct', 'resolution_factor', 'RatioDw_Dg', 'th_matter', 'th_necro', 'dx_mm', 'dy_mm', 'dz_mm', 'init_scale', 'time_series_solution_Nt', 'Nt_multiplier', 'output_dir']
# Example params: {'Dw': 1.459503618461283, 'rho': 0.7087988562347525}

# %%
TARGET_KEYS = ("Dw", "rho")

# %%
import random
random.seed(42)
random.shuffle(samples)

n = len(samples)
train = samples[:int(0.7*n)]
val   = samples[int(0.7*n):int(0.85*n)]
test  = samples[int(0.85*n):]

print("Split sizes:", len(train), len(val), len(test))
# Out:
# Split sizes: 175 37 38

# %%
import numpy as np
import json

def get_y(sample_dir):
    p = json.loads((sample_dir/"parameters.json").read_text())
    vals = []
    for k in TARGET_KEYS:
        v = float(p[k])
        if k == "Dw":
            v = np.log(v)
        vals.append(v)
    return np.array(vals, dtype=np.float32)

Y_train = np.stack([get_y(s) for s in train], axis=0)
Y_MEAN = Y_train.mean(axis=0)
Y_STD  = Y_train.std(axis=0) + 1e-6

print("Y_MEAN:", Y_MEAN)
print("Y_STD :", Y_STD)
# Out:
# Y_MEAN: [0.34416467 0.3797969 ]
# Y_STD : [0.9162873  0.23868617]

# %%
import numpy as np
import SimpleITK as sitk
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
import json

def read_nii(path):
    img = sitk.ReadImage(str(path))
    arr = sitk.GetArrayFromImage(img).astype(np.float32)  # (D,H,W)
    return arr

def bbox_from_mask(mask, margin=12):
    idx = np.argwhere(mask)
    if idx.size == 0:
        return None
    z0,y0,x0 = idx.min(axis=0)
    z1,y1,x1 = idx.max(axis=0) + 1
    z0 = max(z0 - margin, 0); y0 = max(y0 - margin, 0); x0 = max(x0 - margin, 0)
    z1 = min(z1 + margin, mask.shape[0]); y1 = min(y1 + margin, mask.shape[1]); x1 = min(x1 + margin, mask.shape[2])
    return (z0,z1,y0,y1,x0,x1)

def crop(arr, bb):
    z0,z1,y0,y1,x0,x1 = bb
    return arr[z0:z1, y0:y1, x0:x1]

def resize_3d(arr, out_shape=(96,96,96)):
    t = torch.from_numpy(arr)[None,None,...]
    t = F.interpolate(t, size=out_shape, mode="trilinear", align_corners=False)
    return t[0,0].numpy()

def normalize_channel(arr):
    m = arr.mean()
    s = arr.std()
    return (arr - m) / (s + 1e-6)

class TumorParamDatasetCached(Dataset):
    """
    Loads + preprocesses every sample once at init, then serves from RAM.
    PNS-only variant: loads P, N, S channels (no segmentation).
    """
    def __init__(self, sample_dirs, out_shape=(96,96,96), target_keys=("Dw","rho"), verbose=True):
        self.sample_dirs = sample_dirs
        self.out_shape = out_shape
        self.target_keys = target_keys

        self.cache = []
        if verbose:
            print(f"Caching {len(sample_dirs)} samples (P+N+S only)... (one-time cost)")

        for i, sd in enumerate(self.sample_dirs):
            x, y = self._load_one(sd)
            self.cache.append((x, y))
            if verbose and (i+1) % 25 == 0:
                print(f"  cached {i+1}/{len(sample_dirs)}")

        if verbose:
            print("Caching done.")

    def __len__(self):
        return len(self.cache)

    def __getitem__(self, idx):
        return self.cache[idx]

    def _load_one(self, sd):
        # ---- Targets (normalized using training stats) ----
        params = json.loads((sd/"parameters.json").read_text())
        vals = []
        for k in self.target_keys:
            v = float(params[k])
            if k == "Dw":
                v = np.log(v)  # <-- log transform
            vals.append(v)

        y_raw = np.array(vals, dtype=np.float32)
        y_norm = (y_raw - Y_MEAN) / Y_STD
        y = torch.tensor(y_norm, dtype=torch.float32)

        # ---- Inputs: P, N, S only (no segmentation) ----
        segm = read_nii(sd/"segm.nii.gz")
        bb = bbox_from_mask(segm > 0, margin=12)

        chans = [
            read_nii(sd/"P.nii.gz"),
            read_nii(sd/"N.nii.gz"),
            read_nii(sd/"S.nii.gz"),
        ]

        processed = []
        for c in chans:
            if bb is not None:
                c = crop(c, bb)
            c = resize_3d(c, self.out_shape)

            # normalize non-binary channels
            if np.unique(c).size > 2:
                c = normalize_channel(c)

            processed.append(c)

        x = torch.from_numpy(np.stack(processed, axis=0)).float()  # (3,D,H,W)
        return x, y

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.cuda.amp import autocast, GradScaler


class CNN3DRegressor(nn.Module):
    def __init__(self, in_channels, out_dim):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv3d(in_channels, 32, 3, padding=1),
            nn.BatchNorm3d(32), nn.ReLU(inplace=True),
            nn.MaxPool3d(2),

            nn.Conv3d(32, 64, 3, padding=1),
            nn.BatchNorm3d(64), nn.ReLU(inplace=True),
            nn.MaxPool3d(2),

            nn.Conv3d(64, 128, 3, padding=1),
            nn.BatchNorm3d(128), nn.ReLU(inplace=True),
            nn.MaxPool3d(2),

            nn.Conv3d(128, 256, 3, padding=1),
            nn.BatchNorm3d(256), nn.ReLU(inplace=True),
        )
        self.head = nn.Sequential(
            nn.AdaptiveAvgPool3d(1),
            nn.Flatten(),
            nn.Linear(256, 128), nn.ReLU(inplace=True),
            nn.Dropout(0.2),
            nn.Linear(128, out_dim)
        )

    def forward(self, x):
        return self.head(self.features(x))

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device, torch.cuda.get_device_name(0) if device=="cuda" else "")

OUT_SHAPE = (96,96,96)

# ---- Cache datasets (one-time preprocessing) ----
train_ds = TumorParamDatasetCached(train, out_shape=OUT_SHAPE, target_keys=TARGET_KEYS, verbose=True)
val_ds   = TumorParamDatasetCached(val,   out_shape=OUT_SHAPE, target_keys=TARGET_KEYS, verbose=True)

# ---- DataLoader settings ----
NUM_WORKERS = 0
BATCH_SIZE = 8

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

model = CNN3DRegressor(in_channels=3, out_dim=len(TARGET_KEYS)).to(device)
opt = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
scaler = GradScaler()
loss_fn = nn.MSELoss()
def mae(pred, y):
    return (pred - y).abs().mean()

EPOCHS = 300 

# ---- Best validation checkpoint ----
best_val_mse = float("inf")
best_state = None
best_epoch = -1

for epoch in range(1, EPOCHS+1):
    model.train()
    tr_loss = tr_mae = 0.0

    for x, y in train_loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        opt.zero_grad(set_to_none=True)
        with autocast():
            pred = model(x)
            loss = loss_fn(pred, y)

        scaler.scale(loss).backward()
        scaler.step(opt)
        scaler.update()

        tr_loss += loss.item()
        tr_mae  += mae(pred.detach(), y).item()

    model.eval()
    va_loss = va_mae = 0.0
    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)
            with autocast():
                pred = model(x)
                loss = loss_fn(pred, y)
            va_loss += loss.item()
            va_mae  += mae(pred, y).item()

    val_mse = va_loss / len(val_loader)

    # Save best model weights
    if val_mse < best_val_mse:
        best_val_mse = val_mse
        best_epoch = epoch
        best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    print(f"Epoch {epoch:03d} | train MSE {tr_loss/len(train_loader):.4f} MAE {tr_mae/len(train_loader):.4f} "
      f"| val MSE {val_mse:.4f} MAE {va_mae/len(val_loader):.4f} "
      f"| best val {best_val_mse:.4f} @ {best_epoch:03d}")

# Restore best model before testing
if best_state is not None:
    model.load_state_dict(best_state)
    print(f"\n✅ Loaded best model from epoch {best_epoch} with val MSE {best_val_mse:.6f}")
# Out:
# Device: cuda NVIDIA GeForce RTX 5080
# Caching 175 samples (P+N+S only)... (one-time cost)
#   cached 25/175
#   cached 50/175
#   cached 75/175
#   cached 100/175
#   cached 125/175
#   cached 150/175
#   cached 175/175
# Caching done.
# Caching 37 samples (P+N+S only)... (one-time cost)
#   cached 25/37
# Caching done.
# C:\Users\Grant\AppData\Local\Temp\ipykernel_37816\428110415.py:55: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# C:\Users\Grant\AppData\Local\Temp\ipykernel_37816\428110415.py:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\Grant\AppData\Local\Temp\ipykernel_37816\428110415.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 001 | train MSE 0.7320 MAE 0.7028 | val MSE 0.8985 MAE 0.7895 | best val 0.8985 @ 001
# Epoch 002 | train MSE 0.5142 MAE 0.5813 | val MSE 0.4072 MAE 0.5340 | best val 0.4072 @ 002
# Epoch 003 | train MSE 0.4263 MAE 0.5198 | val MSE 0.4926 MAE 0.5006 | best val 0.4072 @ 002
# Epoch 004 | train MSE 0.3915 MAE 0.4961 | val MSE 0.3247 MAE 0.4518 | best val 0.3247 @ 004
# Epoch 005 | train MSE 0.4689 MAE 0.5291 | val MSE 0.2826 MAE 0.4291 | best val 0.2826 @ 005
# Epoch 006 | train MSE 0.3340 MAE 0.4613 | val MSE 0.2785 MAE 0.4051 | best val 0.2785 @ 006
# Epoch 007 | train MSE 0.4204 MAE 0.5061 | val MSE 0.4111 MAE 0.5442 | best val 0.2785 @ 006
# Epoch 008 | train MSE 0.3436 MAE 0.4674 | val MSE 0.2447 MAE 0.3958 | best val 0.2447 @ 008
# Epoch 009 | train MSE 0.2997 MAE 0.4221 | val MSE 0.2055 MAE 0.3434 | best val 0.2055 @ 009
# Epoch 010 | train MSE 0.3019 MAE 0.4396 | val MSE 0.2444 MAE 0.3664 | best val 0.2055 @ 009
# Epoch 011 | train MSE 0.2635 MAE 0.3983 | val MSE 0.2311 MAE 0.3811 | best val 0.2055 @ 009
# Epoch 012 | train MSE 0.2987 MAE 0.4351 | val MSE 0.2621 MAE 0.3857 | best val 0.2055 @ 009
# Epoch 013 | train MSE 0.3332 MAE 0.4527 | val MSE 0.2181 MAE 0.3520 | best val 0.2055 @ 009
# Epoch 014 | train MSE 0.3480 MAE 0.4715 | val MSE 0.4017 MAE 0.5337 | best val 0.2055 @ 009
# Epoch 015 | train MSE 0.2900 MAE 0.4168 | val MSE 0.2118 MAE 0.3347 | best val 0.2055 @ 009
# Epoch 016 | train MSE 0.2886 MAE 0.4118 | val MSE 0.2317 MAE 0.3903 | best val 0.2055 @ 009
# Epoch 017 | train MSE 0.3307 MAE 0.4550 | val MSE 0.2356 MAE 0.3628 | best val 0.2055 @ 009
# Epoch 018 | train MSE 0.2812 MAE 0.4202 | val MSE 0.1938 MAE 0.3318 | best val 0.1938 @ 018
# Epoch 019 | train MSE 0.2151 MAE 0.3615 | val MSE 0.2148 MAE 0.3661 | best val 0.1938 @ 018
# Epoch 020 | train MSE 0.2286 MAE 0.3761 | val MSE 0.2049 MAE 0.3441 | best val 0.1938 @ 018
# Epoch 021 | train MSE 0.2486 MAE 0.3907 | val MSE 0.2010 MAE 0.3279 | best val 0.1938 @ 018
# Epoch 022 | train MSE 0.2786 MAE 0.4039 | val MSE 0.2146 MAE 0.3526 | best val 0.1938 @ 018
# Epoch 023 | train MSE 0.2918 MAE 0.4250 | val MSE 0.3603 MAE 0.4596 | best val 0.1938 @ 018
# Epoch 024 | train MSE 0.2264 MAE 0.3678 | val MSE 0.2299 MAE 0.3865 | best val 0.1938 @ 018
# Epoch 025 | train MSE 0.2459 MAE 0.3897 | val MSE 0.1554 MAE 0.3006 | best val 0.1554 @ 025
# Epoch 026 | train MSE 0.2273 MAE 0.3705 | val MSE 0.1951 MAE 0.3383 | best val 0.1554 @ 025
# Epoch 027 | train MSE 0.2295 MAE 0.3687 | val MSE 0.2198 MAE 0.3617 | best val 0.1554 @ 025
# Epoch 028 | train MSE 0.2413 MAE 0.3882 | val MSE 0.2149 MAE 0.3732 | best val 0.1554 @ 025
# Epoch 029 | train MSE 0.2470 MAE 0.3901 | val MSE 0.2451 MAE 0.4090 | best val 0.1554 @ 025
# Epoch 030 | train MSE 0.2089 MAE 0.3555 | val MSE 0.1575 MAE 0.3051 | best val 0.1554 @ 025
# Epoch 031 | train MSE 0.2158 MAE 0.3746 | val MSE 0.1876 MAE 0.3542 | best val 0.1554 @ 025
# Epoch 032 | train MSE 0.2165 MAE 0.3631 | val MSE 0.2647 MAE 0.4242 | best val 0.1554 @ 025
# Epoch 033 | train MSE 0.1870 MAE 0.3401 | val MSE 0.2180 MAE 0.3424 | best val 0.1554 @ 025
# Epoch 034 | train MSE 0.2213 MAE 0.3697 | val MSE 0.1460 MAE 0.2844 | best val 0.1460 @ 034
# Epoch 035 | train MSE 0.2760 MAE 0.4022 | val MSE 0.3836 MAE 0.4949 | best val 0.1460 @ 034
# Epoch 036 | train MSE 0.2205 MAE 0.3640 | val MSE 0.3250 MAE 0.4668 | best val 0.1460 @ 034
# Epoch 037 | train MSE 0.2514 MAE 0.3934 | val MSE 0.1806 MAE 0.3065 | best val 0.1460 @ 034
# Epoch 038 | train MSE 0.1734 MAE 0.3262 | val MSE 0.1747 MAE 0.3014 | best val 0.1460 @ 034
# Epoch 039 | train MSE 0.2104 MAE 0.3674 | val MSE 0.1852 MAE 0.3507 | best val 0.1460 @ 034
# Epoch 040 | train MSE 0.2131 MAE 0.3734 | val MSE 0.1543 MAE 0.3094 | best val 0.1460 @ 034
# Epoch 041 | train MSE 0.2058 MAE 0.3516 | val MSE 0.1990 MAE 0.3297 | best val 0.1460 @ 034
# Epoch 042 | train MSE 0.2043 MAE 0.3669 | val MSE 0.1446 MAE 0.2922 | best val 0.1446 @ 042
# Epoch 043 | train MSE 0.2108 MAE 0.3658 | val MSE 0.3308 MAE 0.4603 | best val 0.1446 @ 042
# Epoch 044 | train MSE 0.1972 MAE 0.3450 | val MSE 0.1757 MAE 0.3150 | best val 0.1446 @ 042
# Epoch 045 | train MSE 0.1957 MAE 0.3360 | val MSE 0.1409 MAE 0.2868 | best val 0.1409 @ 045
# Epoch 046 | train MSE 0.2060 MAE 0.3498 | val MSE 0.1700 MAE 0.3450 | best val 0.1409 @ 045
# Epoch 047 | train MSE 0.1770 MAE 0.3273 | val MSE 0.1385 MAE 0.2673 | best val 0.1385 @ 047
# Epoch 048 | train MSE 0.2023 MAE 0.3575 | val MSE 0.1648 MAE 0.3154 | best val 0.1385 @ 047
# Epoch 049 | train MSE 0.1809 MAE 0.3321 | val MSE 0.1872 MAE 0.3159 | best val 0.1385 @ 047
# Epoch 050 | train MSE 0.1917 MAE 0.3455 | val MSE 0.1365 MAE 0.2788 | best val 0.1365 @ 050
# Epoch 051 | train MSE 0.1680 MAE 0.3108 | val MSE 0.1214 MAE 0.2568 | best val 0.1214 @ 051
# Epoch 052 | train MSE 0.1602 MAE 0.3102 | val MSE 0.1896 MAE 0.3483 | best val 0.1214 @ 051
# Epoch 053 | train MSE 0.2086 MAE 0.3598 | val MSE 0.2486 MAE 0.4034 | best val 0.1214 @ 051
# Epoch 054 | train MSE 0.2304 MAE 0.3736 | val MSE 0.1821 MAE 0.3353 | best val 0.1214 @ 051
# Epoch 055 | train MSE 0.1765 MAE 0.3288 | val MSE 0.1602 MAE 0.3008 | best val 0.1214 @ 051
# Epoch 056 | train MSE 0.1874 MAE 0.3394 | val MSE 0.1438 MAE 0.3046 | best val 0.1214 @ 051
# Epoch 057 | train MSE 0.1656 MAE 0.3177 | val MSE 0.1660 MAE 0.3201 | best val 0.1214 @ 051
# Epoch 058 | train MSE 0.1591 MAE 0.3187 | val MSE 0.1269 MAE 0.2801 | best val 0.1214 @ 051
# Epoch 059 | train MSE 0.1527 MAE 0.3013 | val MSE 0.1712 MAE 0.3279 | best val 0.1214 @ 051
# Epoch 060 | train MSE 0.1453 MAE 0.2977 | val MSE 0.3135 MAE 0.4503 | best val 0.1214 @ 051
# Epoch 061 | train MSE 0.1949 MAE 0.3498 | val MSE 0.3614 MAE 0.4828 | best val 0.1214 @ 051
# Epoch 062 | train MSE 0.2147 MAE 0.3651 | val MSE 0.1473 MAE 0.2873 | best val 0.1214 @ 051
# Epoch 063 | train MSE 0.1807 MAE 0.3354 | val MSE 0.1561 MAE 0.3200 | best val 0.1214 @ 051
# Epoch 064 | train MSE 0.1818 MAE 0.3351 | val MSE 0.1742 MAE 0.2957 | best val 0.1214 @ 051
# Epoch 065 | train MSE 0.1814 MAE 0.3351 | val MSE 0.1176 MAE 0.2491 | best val 0.1176 @ 065
# Epoch 066 | train MSE 0.1382 MAE 0.2961 | val MSE 0.1732 MAE 0.2929 | best val 0.1176 @ 065
# Epoch 067 | train MSE 0.1589 MAE 0.3181 | val MSE 0.1512 MAE 0.2847 | best val 0.1176 @ 065
# Epoch 068 | train MSE 0.1652 MAE 0.3268 | val MSE 0.1655 MAE 0.3082 | best val 0.1176 @ 065
# Epoch 069 | train MSE 0.1693 MAE 0.3206 | val MSE 0.1332 MAE 0.2782 | best val 0.1176 @ 065
# Epoch 070 | train MSE 0.1611 MAE 0.3145 | val MSE 0.1402 MAE 0.2665 | best val 0.1176 @ 065
# Epoch 071 | train MSE 0.1352 MAE 0.2922 | val MSE 0.1235 MAE 0.2500 | best val 0.1176 @ 065
# Epoch 072 | train MSE 0.1574 MAE 0.3204 | val MSE 0.2037 MAE 0.3315 | best val 0.1176 @ 065
# Epoch 073 | train MSE 0.1645 MAE 0.3254 | val MSE 0.1511 MAE 0.2820 | best val 0.1176 @ 065
# Epoch 074 | train MSE 0.1347 MAE 0.2841 | val MSE 0.1503 MAE 0.2887 | best val 0.1176 @ 065
# Epoch 075 | train MSE 0.1204 MAE 0.2803 | val MSE 0.1260 MAE 0.2549 | best val 0.1176 @ 065
# Epoch 076 | train MSE 0.1140 MAE 0.2599 | val MSE 0.1636 MAE 0.3107 | best val 0.1176 @ 065
# Epoch 077 | train MSE 0.1507 MAE 0.3062 | val MSE 0.1235 MAE 0.2455 | best val 0.1176 @ 065
# Epoch 078 | train MSE 0.1444 MAE 0.2922 | val MSE 0.1823 MAE 0.3250 | best val 0.1176 @ 065
# Epoch 079 | train MSE 0.1467 MAE 0.2998 | val MSE 0.1938 MAE 0.3368 | best val 0.1176 @ 065
# Epoch 080 | train MSE 0.1432 MAE 0.3023 | val MSE 0.1483 MAE 0.2960 | best val 0.1176 @ 065
# Epoch 081 | train MSE 0.1268 MAE 0.2726 | val MSE 0.1664 MAE 0.3051 | best val 0.1176 @ 065
# Epoch 082 | train MSE 0.1333 MAE 0.2837 | val MSE 0.1341 MAE 0.2669 | best val 0.1176 @ 065
# Epoch 083 | train MSE 0.1430 MAE 0.2979 | val MSE 0.1676 MAE 0.3111 | best val 0.1176 @ 065
# Epoch 084 | train MSE 0.1392 MAE 0.2888 | val MSE 0.2240 MAE 0.3729 | best val 0.1176 @ 065
# Epoch 085 | train MSE 0.1466 MAE 0.2946 | val MSE 0.1426 MAE 0.2844 | best val 0.1176 @ 065
# Epoch 086 | train MSE 0.1323 MAE 0.2902 | val MSE 0.1429 MAE 0.2698 | best val 0.1176 @ 065
# Epoch 087 | train MSE 0.1533 MAE 0.3047 | val MSE 0.1691 MAE 0.2863 | best val 0.1176 @ 065
# Epoch 088 | train MSE 0.1176 MAE 0.2667 | val MSE 0.1311 MAE 0.2617 | best val 0.1176 @ 065
# Epoch 089 | train MSE 0.1437 MAE 0.2798 | val MSE 0.2413 MAE 0.3943 | best val 0.1176 @ 065
# Epoch 090 | train MSE 0.1254 MAE 0.2809 | val MSE 0.1717 MAE 0.3464 | best val 0.1176 @ 065
# Epoch 091 | train MSE 0.1392 MAE 0.2903 | val MSE 0.1677 MAE 0.2933 | best val 0.1176 @ 065
# Epoch 092 | train MSE 0.1484 MAE 0.2941 | val MSE 0.1730 MAE 0.2913 | best val 0.1176 @ 065
# Epoch 093 | train MSE 0.1214 MAE 0.2741 | val MSE 0.1560 MAE 0.2759 | best val 0.1176 @ 065
# Epoch 094 | train MSE 0.1311 MAE 0.2801 | val MSE 0.1580 MAE 0.2853 | best val 0.1176 @ 065
# Epoch 095 | train MSE 0.1491 MAE 0.2956 | val MSE 0.1450 MAE 0.2791 | best val 0.1176 @ 065
# Epoch 096 | train MSE 0.1215 MAE 0.2710 | val MSE 0.1732 MAE 0.3046 | best val 0.1176 @ 065
# Epoch 097 | train MSE 0.1438 MAE 0.2841 | val MSE 0.1784 MAE 0.3117 | best val 0.1176 @ 065
# Epoch 098 | train MSE 0.1345 MAE 0.2918 | val MSE 0.2260 MAE 0.3493 | best val 0.1176 @ 065
# Epoch 099 | train MSE 0.1383 MAE 0.2907 | val MSE 0.2230 MAE 0.3606 | best val 0.1176 @ 065
# Epoch 100 | train MSE 0.1186 MAE 0.2646 | val MSE 0.1562 MAE 0.2871 | best val 0.1176 @ 065
# Epoch 101 | train MSE 0.1425 MAE 0.2880 | val MSE 0.2248 MAE 0.3662 | best val 0.1176 @ 065
# Epoch 102 | train MSE 0.1322 MAE 0.2896 | val MSE 0.1844 MAE 0.3011 | best val 0.1176 @ 065
# Epoch 103 | train MSE 0.1425 MAE 0.3054 | val MSE 0.1624 MAE 0.2988 | best val 0.1176 @ 065
# Epoch 104 | train MSE 0.1285 MAE 0.2731 | val MSE 0.1788 MAE 0.3202 | best val 0.1176 @ 065
# Epoch 105 | train MSE 0.1145 MAE 0.2647 | val MSE 0.1505 MAE 0.2866 | best val 0.1176 @ 065
# Epoch 106 | train MSE 0.1161 MAE 0.2652 | val MSE 0.1686 MAE 0.3270 | best val 0.1176 @ 065
# Epoch 107 | train MSE 0.1103 MAE 0.2582 | val MSE 0.1530 MAE 0.2611 | best val 0.1176 @ 065
# Epoch 108 | train MSE 0.1048 MAE 0.2435 | val MSE 0.1266 MAE 0.2420 | best val 0.1176 @ 065
# Epoch 109 | train MSE 0.1181 MAE 0.2712 | val MSE 0.2621 MAE 0.4068 | best val 0.1176 @ 065
# Epoch 110 | train MSE 0.1461 MAE 0.3055 | val MSE 0.1817 MAE 0.3081 | best val 0.1176 @ 065
# Epoch 111 | train MSE 0.1031 MAE 0.2457 | val MSE 0.1578 MAE 0.2832 | best val 0.1176 @ 065
# Epoch 112 | train MSE 0.1071 MAE 0.2485 | val MSE 0.1527 MAE 0.2784 | best val 0.1176 @ 065
# Epoch 113 | train MSE 0.1283 MAE 0.2836 | val MSE 0.1201 MAE 0.2434 | best val 0.1176 @ 065
# Epoch 114 | train MSE 0.1412 MAE 0.2958 | val MSE 0.1316 MAE 0.2572 | best val 0.1176 @ 065
# Epoch 115 | train MSE 0.1144 MAE 0.2545 | val MSE 0.2242 MAE 0.3859 | best val 0.1176 @ 065
# Epoch 116 | train MSE 0.1316 MAE 0.2759 | val MSE 0.1905 MAE 0.3022 | best val 0.1176 @ 065
# Epoch 117 | train MSE 0.1042 MAE 0.2400 | val MSE 0.1984 MAE 0.3317 | best val 0.1176 @ 065
# Epoch 118 | train MSE 0.1017 MAE 0.2490 | val MSE 0.1701 MAE 0.2951 | best val 0.1176 @ 065
# Epoch 119 | train MSE 0.1193 MAE 0.2669 | val MSE 0.1740 MAE 0.3323 | best val 0.1176 @ 065
# Epoch 120 | train MSE 0.1302 MAE 0.2911 | val MSE 0.1445 MAE 0.2741 | best val 0.1176 @ 065
# Epoch 121 | train MSE 0.1255 MAE 0.2769 | val MSE 0.1459 MAE 0.2843 | best val 0.1176 @ 065
# Epoch 122 | train MSE 0.1166 MAE 0.2566 | val MSE 0.1241 MAE 0.2587 | best val 0.1176 @ 065
# Epoch 123 | train MSE 0.1266 MAE 0.2757 | val MSE 0.1478 MAE 0.2745 | best val 0.1176 @ 065
# Epoch 124 | train MSE 0.1216 MAE 0.2690 | val MSE 0.2198 MAE 0.3240 | best val 0.1176 @ 065
# Epoch 125 | train MSE 0.0928 MAE 0.2431 | val MSE 0.1179 MAE 0.2395 | best val 0.1176 @ 065
# Epoch 126 | train MSE 0.1218 MAE 0.2687 | val MSE 0.1241 MAE 0.2617 | best val 0.1176 @ 065
# Epoch 127 | train MSE 0.1026 MAE 0.2468 | val MSE 0.1299 MAE 0.2547 | best val 0.1176 @ 065
# Epoch 128 | train MSE 0.0835 MAE 0.2204 | val MSE 0.2351 MAE 0.3814 | best val 0.1176 @ 065
# Epoch 129 | train MSE 0.0938 MAE 0.2389 | val MSE 0.1886 MAE 0.3156 | best val 0.1176 @ 065
# Epoch 130 | train MSE 0.1125 MAE 0.2665 | val MSE 0.1504 MAE 0.2702 | best val 0.1176 @ 065
# Epoch 131 | train MSE 0.1018 MAE 0.2489 | val MSE 0.1485 MAE 0.2790 | best val 0.1176 @ 065
# Epoch 132 | train MSE 0.1103 MAE 0.2597 | val MSE 0.1569 MAE 0.2805 | best val 0.1176 @ 065
# Epoch 133 | train MSE 0.1117 MAE 0.2553 | val MSE 0.1961 MAE 0.3078 | best val 0.1176 @ 065
# Epoch 134 | train MSE 0.1029 MAE 0.2505 | val MSE 0.1584 MAE 0.2783 | best val 0.1176 @ 065
# Epoch 135 | train MSE 0.0835 MAE 0.2278 | val MSE 0.1293 MAE 0.2649 | best val 0.1176 @ 065
# Epoch 136 | train MSE 0.0935 MAE 0.2336 | val MSE 0.1580 MAE 0.2932 | best val 0.1176 @ 065
# Epoch 137 | train MSE 0.0936 MAE 0.2372 | val MSE 0.1357 MAE 0.2573 | best val 0.1176 @ 065
# Epoch 138 | train MSE 0.1102 MAE 0.2564 | val MSE 0.2314 MAE 0.3870 | best val 0.1176 @ 065
# Epoch 139 | train MSE 0.0891 MAE 0.2329 | val MSE 0.1463 MAE 0.2732 | best val 0.1176 @ 065
# Epoch 140 | train MSE 0.0945 MAE 0.2415 | val MSE 0.1697 MAE 0.3000 | best val 0.1176 @ 065
# Epoch 141 | train MSE 0.1092 MAE 0.2619 | val MSE 0.1554 MAE 0.2771 | best val 0.1176 @ 065
# Epoch 142 | train MSE 0.1594 MAE 0.3064 | val MSE 0.1698 MAE 0.3081 | best val 0.1176 @ 065
# Epoch 143 | train MSE 0.1305 MAE 0.2872 | val MSE 0.2500 MAE 0.3914 | best val 0.1176 @ 065
# Epoch 144 | train MSE 0.1042 MAE 0.2463 | val MSE 0.2028 MAE 0.3331 | best val 0.1176 @ 065
# Epoch 145 | train MSE 0.0953 MAE 0.2368 | val MSE 0.1355 MAE 0.2597 | best val 0.1176 @ 065
# Epoch 146 | train MSE 0.1134 MAE 0.2629 | val MSE 0.1235 MAE 0.2430 | best val 0.1176 @ 065
# Epoch 147 | train MSE 0.1095 MAE 0.2567 | val MSE 0.1632 MAE 0.2963 | best val 0.1176 @ 065
# Epoch 148 | train MSE 0.1025 MAE 0.2503 | val MSE 0.1617 MAE 0.3001 | best val 0.1176 @ 065
# Epoch 149 | train MSE 0.1138 MAE 0.2512 | val MSE 0.1754 MAE 0.3048 | best val 0.1176 @ 065
# Epoch 150 | train MSE 0.0956 MAE 0.2424 | val MSE 0.1468 MAE 0.2704 | best val 0.1176 @ 065
# Epoch 151 | train MSE 0.0902 MAE 0.2329 | val MSE 0.1189 MAE 0.2498 | best val 0.1176 @ 065
# Epoch 152 | train MSE 0.0948 MAE 0.2330 | val MSE 0.1435 MAE 0.2907 | best val 0.1176 @ 065
# Epoch 153 | train MSE 0.0914 MAE 0.2363 | val MSE 0.1394 MAE 0.2706 | best val 0.1176 @ 065
# Epoch 154 | train MSE 0.0826 MAE 0.2200 | val MSE 0.1587 MAE 0.3108 | best val 0.1176 @ 065
# Epoch 155 | train MSE 0.0838 MAE 0.2286 | val MSE 0.1731 MAE 0.2927 | best val 0.1176 @ 065
# Epoch 156 | train MSE 0.0786 MAE 0.2221 | val MSE 0.1482 MAE 0.2652 | best val 0.1176 @ 065
# Epoch 157 | train MSE 0.0917 MAE 0.2361 | val MSE 0.1806 MAE 0.3176 | best val 0.1176 @ 065
# Epoch 158 | train MSE 0.0881 MAE 0.2260 | val MSE 0.1918 MAE 0.3515 | best val 0.1176 @ 065
# Epoch 159 | train MSE 0.0986 MAE 0.2464 | val MSE 0.1873 MAE 0.3137 | best val 0.1176 @ 065
# Epoch 160 | train MSE 0.0960 MAE 0.2471 | val MSE 0.1399 MAE 0.2671 | best val 0.1176 @ 065
# Epoch 161 | train MSE 0.0959 MAE 0.2394 | val MSE 0.1615 MAE 0.3001 | best val 0.1176 @ 065
# Epoch 162 | train MSE 0.0973 MAE 0.2434 | val MSE 0.1496 MAE 0.2615 | best val 0.1176 @ 065
# Epoch 163 | train MSE 0.0984 MAE 0.2464 | val MSE 0.1793 MAE 0.3143 | best val 0.1176 @ 065
# Epoch 164 | train MSE 0.0999 MAE 0.2528 | val MSE 0.1581 MAE 0.2752 | best val 0.1176 @ 065
# Epoch 165 | train MSE 0.0846 MAE 0.2251 | val MSE 0.1940 MAE 0.3325 | best val 0.1176 @ 065
# Epoch 166 | train MSE 0.0903 MAE 0.2413 | val MSE 0.2218 MAE 0.3622 | best val 0.1176 @ 065
# Epoch 167 | train MSE 0.1081 MAE 0.2618 | val MSE 0.1611 MAE 0.2863 | best val 0.1176 @ 065
# Epoch 168 | train MSE 0.1038 MAE 0.2558 | val MSE 0.1902 MAE 0.3200 | best val 0.1176 @ 065
# Epoch 169 | train MSE 0.1032 MAE 0.2490 | val MSE 0.1702 MAE 0.2920 | best val 0.1176 @ 065
# Epoch 170 | train MSE 0.1127 MAE 0.2557 | val MSE 0.1340 MAE 0.2565 | best val 0.1176 @ 065
# Epoch 171 | train MSE 0.1110 MAE 0.2655 | val MSE 0.2039 MAE 0.3182 | best val 0.1176 @ 065
# Epoch 172 | train MSE 0.0799 MAE 0.2202 | val MSE 0.1686 MAE 0.3154 | best val 0.1176 @ 065
# Epoch 173 | train MSE 0.0910 MAE 0.2349 | val MSE 0.1927 MAE 0.3319 | best val 0.1176 @ 065
# Epoch 174 | train MSE 0.0951 MAE 0.2460 | val MSE 0.1538 MAE 0.2769 | best val 0.1176 @ 065
# Epoch 175 | train MSE 0.0965 MAE 0.2454 | val MSE 0.1613 MAE 0.2917 | best val 0.1176 @ 065
# Epoch 176 | train MSE 0.0843 MAE 0.2263 | val MSE 0.1522 MAE 0.2727 | best val 0.1176 @ 065
# Epoch 177 | train MSE 0.0971 MAE 0.2421 | val MSE 0.2269 MAE 0.3396 | best val 0.1176 @ 065
# Epoch 178 | train MSE 0.0863 MAE 0.2260 | val MSE 0.1614 MAE 0.2676 | best val 0.1176 @ 065
# Epoch 179 | train MSE 0.0844 MAE 0.2229 | val MSE 0.1481 MAE 0.2839 | best val 0.1176 @ 065
# Epoch 180 | train MSE 0.0824 MAE 0.2276 | val MSE 0.1313 MAE 0.2551 | best val 0.1176 @ 065
# Epoch 181 | train MSE 0.0851 MAE 0.2279 | val MSE 0.1606 MAE 0.2748 | best val 0.1176 @ 065
# Epoch 182 | train MSE 0.0883 MAE 0.2306 | val MSE 0.1789 MAE 0.3056 | best val 0.1176 @ 065
# Epoch 183 | train MSE 0.0732 MAE 0.2176 | val MSE 0.1217 MAE 0.2653 | best val 0.1176 @ 065
# Epoch 184 | train MSE 0.0862 MAE 0.2220 | val MSE 0.1516 MAE 0.2968 | best val 0.1176 @ 065
# Epoch 185 | train MSE 0.0719 MAE 0.2086 | val MSE 0.1774 MAE 0.2969 | best val 0.1176 @ 065
# Epoch 186 | train MSE 0.0845 MAE 0.2252 | val MSE 0.1728 MAE 0.2798 | best val 0.1176 @ 065
# Epoch 187 | train MSE 0.1005 MAE 0.2416 | val MSE 0.1734 MAE 0.2889 | best val 0.1176 @ 065
# Epoch 188 | train MSE 0.0981 MAE 0.2388 | val MSE 0.1544 MAE 0.3007 | best val 0.1176 @ 065
# Epoch 189 | train MSE 0.0882 MAE 0.2323 | val MSE 0.1439 MAE 0.2643 | best val 0.1176 @ 065
# Epoch 190 | train MSE 0.0977 MAE 0.2431 | val MSE 0.1425 MAE 0.2801 | best val 0.1176 @ 065
# Epoch 191 | train MSE 0.0852 MAE 0.2229 | val MSE 0.1598 MAE 0.2810 | best val 0.1176 @ 065
# Epoch 192 | train MSE 0.0788 MAE 0.2190 | val MSE 0.1787 MAE 0.2940 | best val 0.1176 @ 065
# Epoch 193 | train MSE 0.1050 MAE 0.2474 | val MSE 0.2321 MAE 0.3303 | best val 0.1176 @ 065
# Epoch 194 | train MSE 0.0865 MAE 0.2242 | val MSE 0.1784 MAE 0.2950 | best val 0.1176 @ 065
# Epoch 195 | train MSE 0.0917 MAE 0.2381 | val MSE 0.1286 MAE 0.2530 | best val 0.1176 @ 065
# Epoch 196 | train MSE 0.0830 MAE 0.2242 | val MSE 0.1378 MAE 0.2770 | best val 0.1176 @ 065
# Epoch 197 | train MSE 0.0710 MAE 0.2122 | val MSE 0.1511 MAE 0.2885 | best val 0.1176 @ 065
# Epoch 198 | train MSE 0.0808 MAE 0.2168 | val MSE 0.1469 MAE 0.2745 | best val 0.1176 @ 065
# Epoch 199 | train MSE 0.0736 MAE 0.2096 | val MSE 0.1391 MAE 0.2645 | best val 0.1176 @ 065
# Epoch 200 | train MSE 0.0797 MAE 0.2171 | val MSE 0.2329 MAE 0.3579 | best val 0.1176 @ 065
# Epoch 201 | train MSE 0.0820 MAE 0.2207 | val MSE 0.1675 MAE 0.3072 | best val 0.1176 @ 065
# Epoch 202 | train MSE 0.0865 MAE 0.2329 | val MSE 0.1508 MAE 0.2831 | best val 0.1176 @ 065
# Epoch 203 | train MSE 0.0810 MAE 0.2279 | val MSE 0.1852 MAE 0.3016 | best val 0.1176 @ 065
# Epoch 204 | train MSE 0.0922 MAE 0.2410 | val MSE 0.1430 MAE 0.2611 | best val 0.1176 @ 065
# Epoch 205 | train MSE 0.0793 MAE 0.2241 | val MSE 0.2021 MAE 0.3303 | best val 0.1176 @ 065
# Epoch 206 | train MSE 0.0836 MAE 0.2257 | val MSE 0.1238 MAE 0.2521 | best val 0.1176 @ 065
# Epoch 207 | train MSE 0.0817 MAE 0.2172 | val MSE 0.1798 MAE 0.3038 | best val 0.1176 @ 065
# Epoch 208 | train MSE 0.0616 MAE 0.1899 | val MSE 0.1371 MAE 0.2499 | best val 0.1176 @ 065
# Epoch 209 | train MSE 0.0769 MAE 0.2160 | val MSE 0.1350 MAE 0.2615 | best val 0.1176 @ 065
# Epoch 210 | train MSE 0.0715 MAE 0.2084 | val MSE 0.1142 MAE 0.2412 | best val 0.1142 @ 210
# Epoch 211 | train MSE 0.0580 MAE 0.1875 | val MSE 0.1498 MAE 0.2759 | best val 0.1142 @ 210
# Epoch 212 | train MSE 0.0737 MAE 0.2129 | val MSE 0.1370 MAE 0.2777 | best val 0.1142 @ 210
# Epoch 213 | train MSE 0.0670 MAE 0.1988 | val MSE 0.1760 MAE 0.3004 | best val 0.1142 @ 210
# Epoch 214 | train MSE 0.0933 MAE 0.2393 | val MSE 0.1711 MAE 0.2867 | best val 0.1142 @ 210
# Epoch 215 | train MSE 0.0693 MAE 0.2026 | val MSE 0.1220 MAE 0.2451 | best val 0.1142 @ 210
# Epoch 216 | train MSE 0.0638 MAE 0.1928 | val MSE 0.1107 MAE 0.2447 | best val 0.1107 @ 216
# Epoch 217 | train MSE 0.0751 MAE 0.2117 | val MSE 0.1256 MAE 0.2527 | best val 0.1107 @ 216
# Epoch 218 | train MSE 0.0729 MAE 0.2079 | val MSE 0.1815 MAE 0.3009 | best val 0.1107 @ 216
# Epoch 219 | train MSE 0.0826 MAE 0.2228 | val MSE 0.1503 MAE 0.2963 | best val 0.1107 @ 216
# Epoch 220 | train MSE 0.0585 MAE 0.1932 | val MSE 0.1485 MAE 0.2950 | best val 0.1107 @ 216
# Epoch 221 | train MSE 0.0749 MAE 0.2107 | val MSE 0.1406 MAE 0.2651 | best val 0.1107 @ 216
# Epoch 222 | train MSE 0.0748 MAE 0.2096 | val MSE 0.1709 MAE 0.2965 | best val 0.1107 @ 216
# Epoch 223 | train MSE 0.0792 MAE 0.2140 | val MSE 0.1504 MAE 0.2847 | best val 0.1107 @ 216
# Epoch 224 | train MSE 0.0716 MAE 0.2026 | val MSE 0.1778 MAE 0.2924 | best val 0.1107 @ 216
# Epoch 225 | train MSE 0.0644 MAE 0.1990 | val MSE 0.1594 MAE 0.2893 | best val 0.1107 @ 216
# Epoch 226 | train MSE 0.0657 MAE 0.1996 | val MSE 0.2096 MAE 0.3449 | best val 0.1107 @ 216
# Epoch 227 | train MSE 0.0771 MAE 0.2210 | val MSE 0.1489 MAE 0.2903 | best val 0.1107 @ 216
# Epoch 228 | train MSE 0.0828 MAE 0.2271 | val MSE 0.1650 MAE 0.2869 | best val 0.1107 @ 216
# Epoch 229 | train MSE 0.0871 MAE 0.2194 | val MSE 0.1786 MAE 0.3042 | best val 0.1107 @ 216
# Epoch 230 | train MSE 0.0677 MAE 0.2033 | val MSE 0.1256 MAE 0.2555 | best val 0.1107 @ 216
# Epoch 231 | train MSE 0.0744 MAE 0.2117 | val MSE 0.1606 MAE 0.2782 | best val 0.1107 @ 216
# Epoch 232 | train MSE 0.0667 MAE 0.1978 | val MSE 0.1681 MAE 0.3004 | best val 0.1107 @ 216
# Epoch 233 | train MSE 0.0906 MAE 0.2405 | val MSE 0.2230 MAE 0.3479 | best val 0.1107 @ 216
# Epoch 234 | train MSE 0.0774 MAE 0.2107 | val MSE 0.1642 MAE 0.2789 | best val 0.1107 @ 216
# Epoch 235 | train MSE 0.0737 MAE 0.2078 | val MSE 0.1815 MAE 0.3081 | best val 0.1107 @ 216
# Epoch 236 | train MSE 0.0699 MAE 0.2013 | val MSE 0.1969 MAE 0.3280 | best val 0.1107 @ 216
# Epoch 237 | train MSE 0.0757 MAE 0.2122 | val MSE 0.1397 MAE 0.2860 | best val 0.1107 @ 216
# Epoch 238 | train MSE 0.0735 MAE 0.2141 | val MSE 0.2240 MAE 0.3412 | best val 0.1107 @ 216
# Epoch 239 | train MSE 0.0751 MAE 0.2107 | val MSE 0.1432 MAE 0.2871 | best val 0.1107 @ 216
# Epoch 240 | train MSE 0.0662 MAE 0.2075 | val MSE 0.1435 MAE 0.2699 | best val 0.1107 @ 216
# Epoch 241 | train MSE 0.0659 MAE 0.1998 | val MSE 0.1555 MAE 0.2889 | best val 0.1107 @ 216
# Epoch 242 | train MSE 0.0890 MAE 0.2318 | val MSE 0.1318 MAE 0.2681 | best val 0.1107 @ 216
# Epoch 243 | train MSE 0.0900 MAE 0.2350 | val MSE 0.1371 MAE 0.2607 | best val 0.1107 @ 216
# Epoch 244 | train MSE 0.0790 MAE 0.2192 | val MSE 0.1960 MAE 0.3356 | best val 0.1107 @ 216
# Epoch 245 | train MSE 0.0717 MAE 0.2138 | val MSE 0.1348 MAE 0.2679 | best val 0.1107 @ 216
# Epoch 246 | train MSE 0.1024 MAE 0.2538 | val MSE 0.2221 MAE 0.3480 | best val 0.1107 @ 216
# Epoch 247 | train MSE 0.1206 MAE 0.2741 | val MSE 0.1414 MAE 0.2804 | best val 0.1107 @ 216
# Epoch 248 | train MSE 0.0827 MAE 0.2271 | val MSE 0.1719 MAE 0.3045 | best val 0.1107 @ 216
# Epoch 249 | train MSE 0.0673 MAE 0.2020 | val MSE 0.1364 MAE 0.2559 | best val 0.1107 @ 216
# Epoch 250 | train MSE 0.0623 MAE 0.1955 | val MSE 0.2026 MAE 0.3118 | best val 0.1107 @ 216
# Epoch 251 | train MSE 0.0669 MAE 0.2036 | val MSE 0.1621 MAE 0.2817 | best val 0.1107 @ 216
# Epoch 252 | train MSE 0.0680 MAE 0.2040 | val MSE 0.1652 MAE 0.2875 | best val 0.1107 @ 216
# Epoch 253 | train MSE 0.0714 MAE 0.2127 | val MSE 0.1693 MAE 0.3127 | best val 0.1107 @ 216
# Epoch 254 | train MSE 0.0689 MAE 0.2074 | val MSE 0.1439 MAE 0.2733 | best val 0.1107 @ 216
# Epoch 255 | train MSE 0.0616 MAE 0.1896 | val MSE 0.1433 MAE 0.2726 | best val 0.1107 @ 216
# Epoch 256 | train MSE 0.0526 MAE 0.1811 | val MSE 0.1673 MAE 0.2929 | best val 0.1107 @ 216
# Epoch 257 | train MSE 0.0582 MAE 0.1881 | val MSE 0.1452 MAE 0.2793 | best val 0.1107 @ 216
# Epoch 258 | train MSE 0.0637 MAE 0.1919 | val MSE 0.1327 MAE 0.2684 | best val 0.1107 @ 216
# Epoch 259 | train MSE 0.0642 MAE 0.1992 | val MSE 0.1517 MAE 0.2754 | best val 0.1107 @ 216
# Epoch 260 | train MSE 0.0588 MAE 0.1844 | val MSE 0.1367 MAE 0.2628 | best val 0.1107 @ 216
# Epoch 261 | train MSE 0.0648 MAE 0.1996 | val MSE 0.1563 MAE 0.2865 | best val 0.1107 @ 216
# Epoch 262 | train MSE 0.0664 MAE 0.1978 | val MSE 0.2523 MAE 0.3310 | best val 0.1107 @ 216
# Epoch 263 | train MSE 0.0604 MAE 0.1865 | val MSE 0.1698 MAE 0.2915 | best val 0.1107 @ 216
# Epoch 264 | train MSE 0.0677 MAE 0.2027 | val MSE 0.1670 MAE 0.2988 | best val 0.1107 @ 216
# Epoch 265 | train MSE 0.0637 MAE 0.1934 | val MSE 0.1670 MAE 0.3118 | best val 0.1107 @ 216
# Epoch 266 | train MSE 0.0835 MAE 0.2147 | val MSE 0.1476 MAE 0.2635 | best val 0.1107 @ 216
# Epoch 267 | train MSE 0.0679 MAE 0.2041 | val MSE 0.1358 MAE 0.2696 | best val 0.1107 @ 216
# Epoch 268 | train MSE 0.0569 MAE 0.1816 | val MSE 0.1652 MAE 0.2870 | best val 0.1107 @ 216
# Epoch 269 | train MSE 0.0766 MAE 0.2074 | val MSE 0.1266 MAE 0.2725 | best val 0.1107 @ 216
# Epoch 270 | train MSE 0.0582 MAE 0.1900 | val MSE 0.1756 MAE 0.3167 | best val 0.1107 @ 216
# Epoch 271 | train MSE 0.0514 MAE 0.1760 | val MSE 0.1498 MAE 0.2716 | best val 0.1107 @ 216
# Epoch 272 | train MSE 0.0655 MAE 0.1986 | val MSE 0.1393 MAE 0.2788 | best val 0.1107 @ 216
# Epoch 273 | train MSE 0.0617 MAE 0.1923 | val MSE 0.1304 MAE 0.2579 | best val 0.1107 @ 216
# Epoch 274 | train MSE 0.0720 MAE 0.2074 | val MSE 0.2548 MAE 0.4068 | best val 0.1107 @ 216
# Epoch 275 | train MSE 0.0702 MAE 0.2141 | val MSE 0.1747 MAE 0.3129 | best val 0.1107 @ 216
# Epoch 276 | train MSE 0.0687 MAE 0.2070 | val MSE 0.2131 MAE 0.3276 | best val 0.1107 @ 216
# Epoch 277 | train MSE 0.0560 MAE 0.1830 | val MSE 0.1937 MAE 0.3203 | best val 0.1107 @ 216
# Epoch 278 | train MSE 0.0501 MAE 0.1759 | val MSE 0.1784 MAE 0.3070 | best val 0.1107 @ 216
# Epoch 279 | train MSE 0.0735 MAE 0.2153 | val MSE 0.1942 MAE 0.3263 | best val 0.1107 @ 216
# Epoch 280 | train MSE 0.0642 MAE 0.1962 | val MSE 0.2325 MAE 0.3748 | best val 0.1107 @ 216
# Epoch 281 | train MSE 0.0705 MAE 0.2021 | val MSE 0.1400 MAE 0.2796 | best val 0.1107 @ 216
# Epoch 282 | train MSE 0.0623 MAE 0.1879 | val MSE 0.1882 MAE 0.2962 | best val 0.1107 @ 216
# Epoch 283 | train MSE 0.0588 MAE 0.1800 | val MSE 0.1245 MAE 0.2674 | best val 0.1107 @ 216
# Epoch 284 | train MSE 0.0665 MAE 0.2022 | val MSE 0.1709 MAE 0.3059 | best val 0.1107 @ 216
# Epoch 285 | train MSE 0.0566 MAE 0.1869 | val MSE 0.1484 MAE 0.2847 | best val 0.1107 @ 216
# Epoch 286 | train MSE 0.0558 MAE 0.1867 | val MSE 0.1519 MAE 0.3066 | best val 0.1107 @ 216
# Epoch 287 | train MSE 0.0691 MAE 0.2039 | val MSE 0.1919 MAE 0.3448 | best val 0.1107 @ 216
# Epoch 288 | train MSE 0.0663 MAE 0.1987 | val MSE 0.1515 MAE 0.2908 | best val 0.1107 @ 216
# Epoch 289 | train MSE 0.0608 MAE 0.1967 | val MSE 0.1473 MAE 0.2930 | best val 0.1107 @ 216
# Epoch 290 | train MSE 0.0589 MAE 0.1916 | val MSE 0.1477 MAE 0.2693 | best val 0.1107 @ 216
# Epoch 291 | train MSE 0.0533 MAE 0.1820 | val MSE 0.1365 MAE 0.2848 | best val 0.1107 @ 216
# Epoch 292 | train MSE 0.0534 MAE 0.1769 | val MSE 0.1739 MAE 0.3000 | best val 0.1107 @ 216
# Epoch 293 | train MSE 0.0505 MAE 0.1719 | val MSE 0.1428 MAE 0.2608 | best val 0.1107 @ 216
# Epoch 294 | train MSE 0.0501 MAE 0.1772 | val MSE 0.1637 MAE 0.3097 | best val 0.1107 @ 216
# Epoch 295 | train MSE 0.0493 MAE 0.1770 | val MSE 0.1479 MAE 0.2972 | best val 0.1107 @ 216
# Epoch 296 | train MSE 0.0555 MAE 0.1844 | val MSE 0.1560 MAE 0.2909 | best val 0.1107 @ 216
# Epoch 297 | train MSE 0.0605 MAE 0.1912 | val MSE 0.1679 MAE 0.3093 | best val 0.1107 @ 216
# Epoch 298 | train MSE 0.0534 MAE 0.1784 | val MSE 0.1477 MAE 0.2764 | best val 0.1107 @ 216
# Epoch 299 | train MSE 0.0601 MAE 0.1921 | val MSE 0.2530 MAE 0.4072 | best val 0.1107 @ 216
# Epoch 300 | train MSE 0.0594 MAE 0.1909 | val MSE 0.1954 MAE 0.3120 | best val 0.1107 @ 216
#
# ✅ Loaded best model from epoch 216 with val MSE 0.110679

# %%
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torch

test_ds = TumorParamDatasetCached(test, out_shape=OUT_SHAPE, target_keys=TARGET_KEYS, verbose=True)
test_loader = DataLoader(test_ds, batch_size=1, shuffle=False, num_workers=0, pin_memory=True)

model.eval()
preds_norm, trues_norm = [], []
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device, non_blocking=True)
        pred = model(x).cpu().numpy()[0]
        preds_norm.append(pred)
        trues_norm.append(y.numpy()[0])

preds_norm = np.array(preds_norm)
trues_norm = np.array(trues_norm)

# Denormalize back to original parameter scale
preds = preds_norm * Y_STD + Y_MEAN
trues = trues_norm * Y_STD + Y_MEAN

# If Dw was trained in log-space, convert it back
for i, k in enumerate(TARGET_KEYS):
    if k == "Dw":
        preds[:, i] = np.exp(preds[:, i])
        trues[:, i] = np.exp(trues[:, i])

for i,k in enumerate(TARGET_KEYS):
    mae_i = np.abs(preds[:,i] - trues[:,i]).mean()
    rmse_i = np.sqrt(((preds[:,i] - trues[:,i])**2).mean())
    print(f"{k}: MAE={mae_i:.6f} RMSE={rmse_i:.6f}")

for i,k in enumerate(TARGET_KEYS):
    plt.figure()
    plt.scatter(trues[:,i], preds[:,i])
    mn = min(trues[:,i].min(), preds[:,i].min())
    mx = max(trues[:,i].max(), preds[:,i].max())
    plt.plot([mn,mx],[mn,mx])
    plt.xlabel("True")
    plt.ylabel("Predicted")
    plt.title(f"{k}: Predicted vs True (P+N+S only)")
    plt.show()
# Out:
# Caching 38 samples (P+N+S only)... (one-time cost)
#   cached 25/38
# Caching done.
# Dw: MAE=0.470397 RMSE=0.641793
# rho: MAE=0.091043 RMSE=0.121964

# %%
import torch

torch.save({
    "model_state": model.state_dict(),
    "target_keys": TARGET_KEYS,
    "out_shape": OUT_SHAPE,
    "y_mean": Y_MEAN,
    "y_std": Y_STD,
    "channels": "P+N+S",
}, "dcnn_param_model_pns_only.pt")

print("Saved -> dcnn_param_model_pns_only.pt")
# Out:
# Saved -> dcnn_param_model_pns_only.pt
